# %% [markdown]
# # Analysis of Z3 (master, commit: fb6e7e1) on HWMCC20 Rules
#
# - Start: Saturday, October 31, 2020 at 13:16:36
# - End: Saturday, October 31, 2020 at 22:01:40
# - Number of benchmarks: 639
# - Timeout: 900 seconds
# - Branch: `z3m-fb6e7e1`
# - Arguments: `-st -v:1 -T:900 fp.xform.slice=true fp.xform.inline_linear=true fp.xform.inline_eager=true fp.xform.tail_simplifier_pve=true fp.engine=spacer fp.print_statistics=true fp.spacer.elim_aux=true fp.spacer.reach_dnf=true fp.spacer.iuc=1 fp.spacer.iuc.arith=1 fp.validate=true fp.spacer.ground_pobs=true fp.spacer.mbqi=false fp.spacer.iuc.print_farkas_stats=false fp.spacer.iuc.old_hyp_reducer=false fp.spacer.ctp=true fp.spacer.weak_abs=true fp.spacer.native_mbp=true`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from typing import List


# noinspection PyUnresolvedReferences
pd.set_option('display.max_rows', None)
# noinspection PyUnresolvedReferences
pd.set_option('display.max_colwidth', None)

sns.set(style='ticks', palette='Set2')
# noinspection PyUnresolvedReferences
plt.rcParams['figure.figsize'] = (10, 10)

# %%
out_dir: str = '../../out/z3m.hwmcc20-rules.lilla-my.31_10_2020-t13-16-36'

filename: str = 'z3m.hwmcc20-rules.lilla-my.31_10_2020-t13-16-36.csv'
df: pd.DataFrame = pd.read_csv(filename)

df['status'].fillna(value='(no status)', inplace=True)

timeout = 900
df['time'].fillna(value=timeout, inplace=True)
df.loc[df['status'] == 'unknown', 'time'] = timeout

# show a snapshot of data for visual validation
df.head()
# Out:
#                                 index  SPACER_cex_depth  \
# 0    array-VexRiscv-regch0-15-p0.smt2               NaN
# 1    array-VexRiscv-regch0-15-p1.smt2               NaN
# 2    array-VexRiscv-regch0-20-p0.smt2               NaN
# 3  array-arbitrated_fifos_n2d8w8.smt2               NaN
# 4               array-array_swap.smt2               NaN
#
#    SPACER_expand_pob_undef  SPACER_inductive_level  SPACER_max_depth  \
# 0                      NaN                     NaN              15.0
# 1                      NaN                     NaN              10.0
# 2                      NaN                     NaN              15.0
# 3                      NaN                     NaN              22.0
# 4                      NaN                     NaN              67.0
#
#    SPACER_max_query_lvl  SPACER_num_active_lemmas  SPACER_num_ctp_blocked  \
# 0                  14.0                     464.0                    96.0
# 1                  10.0                     126.0                    13.0
# 2                  14.0                     561.0                    73.0
# 3                  21.0                     986.0                    20.0
# 4                  66.0                     248.0                    65.0
#
#    SPACER_num_invariants  SPACER_num_is_invariant  ...  time_spacer_ctp  \
# 0                  325.0                   1216.0  ...             0.28
# 1                   79.0                    196.0  ...             0.01
# 2                  384.0                   1406.0  ...             0.76
# 3                   47.0                   8086.0  ...             0.00
# 4                    NaN                  11721.0  ...             0.00
#
#    time_spacer_init_rules  time_spacer_init_rules_pt_init  time_spacer_mbp  \
# 0                    0.06                            0.06             7.86
# 1                    0.06                            0.06             1.69
# 2                    0.06                            0.06             8.72
# 3                    0.01                            0.00             4.87
# 4                    0.00                             NaN             1.07
#
#    time_spacer_solve  time_spacer_solve_propagate  time_spacer_solve_reach  \
# 0             871.28                        83.78                   787.45
# 1              80.99                         3.91                    77.05
# 2             754.59                        76.39                   678.16
# 3             847.21                       289.88                   557.26
# 4             888.55                       544.79                   343.53
#
#    time_spacer_solve_reach_children  time_spacer_solve_reach_gen_bool_ind  \
# 0                             10.75                                653.80
# 1                              2.54                                 59.24
# 2                             12.29                                545.91
# 3                              7.25                                424.13
# 4                              3.97                                 22.48
#
#   time_spacer_solve_reach_is_reach
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
# [5 rows x 39 columns]

# %%
# quick overview of solved/unsolved instances
df[['status', 'index']].groupby('status').count()
# Out:
#              index
# status
# (no status)      7
# sat             23
# timeout        247
# unknown         91
# unsat          271

# %%
df.query('status == "(no status)"')[['index', 'status']]
# Out:
#                                    index       status
# 134           array-easy_zero_array.smt2  (no status)
# 135  array-marlann_compute_fail1-p0.smt2  (no status)
# 138  array-marlann_compute_fail2-p1.smt2  (no status)
# 139  array-marlann_compute_fail2-p2.smt2  (no status)
# 158     array-picorv32_mutBY_mem-p8.smt2  (no status)
# 425    bv-frogs.5.prop1-func-interl.smt2  (no status)
# 619           bv-zipcpu-pfcache-p24.smt2  (no status)

# %%
# Find unknown results. Usually means that something went wrong, not just timeout.
unknown_df: pd.DataFrame = df.query('status == "unknown"')[['index', 'status']]

def get_error(index: str) -> str:
    with open(os.path.join(out_dir, index)) as f:
        return f.readline().strip()

unknown_df['error'] = unknown_df['index'].apply(get_error)
unknown_df.sort_values('error').head()
# Out:
#                                     index   status  \
# 228  array-zipcpu_zipcpu_dcache-p519.smt2  unknown
# 269   array-zipcpu_zipcpu_piped-p211.smt2  unknown
# 262   array-zipcpu_zipcpu_piped-p162.smt2  unknown
# 257   array-zipcpu_zipcpu_piped-p142.smt2  unknown
# 256   array-zipcpu_zipcpu_piped-p132.smt2  unknown
#
#                                                            error
# 228  (error "query failed: could not evaluate Boolean in model")
# 269  (error "query failed: could not evaluate Boolean in model")
# 262  (error "query failed: could not evaluate Boolean in model")
# 257  (error "query failed: could not evaluate Boolean in model")
# 256  (error "query failed: could not evaluate Boolean in model")

# %%
unknown_df.groupby('error')[['index']].agg(['first', 'count'])
# Out:
#                                                                                                                                  index  \
#                                                                                                                                  first
# error
# (error "query failed: could not evaluate Boolean in model")                                           array-picorv32_mutAY_mem-p5.smt2
# (error "query failed: rule validation failed when checking: (exists ((x!1 (_ BitVec 32))              array-picorv32_mutCY_mem-p8.smt2
# (error "query failed: rule validation failed when checking: (exists ((x!1 (_ BitVec 9))          bv-dspfilters_fastfir_second-p07.smt2
# (error "query failed: rule validation failed when checking: (exists ((x!1 Bool)           array-dblclockfft_butterfly_ck3_r2-p148.smt2
# unknown                                                                                               array-VexRiscv-regch0-15-p1.smt2
#
#
#                                                                                          count
# error
# (error "query failed: could not evaluate Boolean in model")                                 71
# (error "query failed: rule validation failed when checking: (exists ((x!1 (_ BitVec 32))     1
# (error "query failed: rule validation failed when checking: (exists ((x!1 (_ BitVec 9))      3
# (error "query failed: rule validation failed when checking: (exists ((x!1 Bool)              2
# unknown                                                                                     14

# %% [markdown]
# ## HWMCC20 modelcheckers

# %%
pd.read_csv('http://fmv.jku.at/hwmcc20/hwmcc20-combined-all.txt', delim_whitespace=True)
# Out:
#          cnt   ok  sat  uns  dis  fld   to  mo  unk    real     time    space  \
# avr      639  547   66  481    0   92    0   0   92   71456  1049649  2282407
# nuxmv    639  500   50  450    0  139  139   0    0   99664   339693   505974
# pono     639  386   58  328    0  253  219  22   12   63789   288937   596666
# cosa2    639  373   58  315    0  266  252   1   13  136153   537672   585138
# btormc   639  333   59  274    0  306  305   0    1   53822    53797    47550
# abc      324  262   56  206    0   62   62   0    0   36505   429078   344728
# abc17    324  262   55  207    0   62   62   0    0   39465   470045   352773
# pdtrav   324  245   45  200    0   79   76   0    3   74891   429930   713508
# avy      324  236   40  196    0   88   88   0    0   44055   437528   426064
# nmtip    324  210   17  193   26   88   88   0    0   24949    24933    17119
# camical  324   43   43    0    0  281  142   0  139   30048    30046     9821
#
#            max  best  uniq
# avr      49141   100    23
# nuxmv     6898    12     2
# pono     77761    38     1
# cosa2    14623    17     0
# btormc    2565   208     2
# abc      31293    29     1
# abc17    31820    10     1
# pdtrav   30090     8     2
# avy      14949    25     0
# nmtip     3117   142    13
# camical    945     8     0

# %%
# The values of the result column are unknown if all model checkers
# gives unknown, or if the number of model checkers that says sat
# and the number of those that say unsat tie. Otherwise, the values
# are sat or unsat based on the majority of the model checkers.
hwmcc20_results: pd.DataFrame = pd.read_csv('../hwmcc20-results.csv')
hwmcc20_results['index'] = hwmcc20_results['index'].apply(lambda idx: idx + '.smt2')
hwmcc20_results.head()
# Out:
#                                 index   result  sat_count  uns_count  \
# 0    array-VexRiscv-regch0-15-p0.smt2    unsat          0          5
# 1    array-VexRiscv-regch0-15-p1.smt2    unsat          0          5
# 2    array-VexRiscv-regch0-20-p0.smt2    unsat          0          4
# 3  array-arbitrated_fifos_n2d8w8.smt2  unknown          0          0
# 4               array-array_swap.smt2  unknown          0          0
#
#    unk_count  low_bound  high_bound  avg_bound  low_real  high_real  avg_real  \
# 0          0         -1          -1       -1.0      9.40    2857.39   586.858
# 1          0         -1          -1       -1.0      9.59    3105.02   641.160
# 2          0         -1          -1       -1.0    228.44    3600.10  1017.224
# 3          2         -1          -1       -1.0      0.74    3600.10  2874.864
# 4          2         -1          -1       -1.0      0.42    3600.10  2875.386
#
#    low_time  high_timeavg_time  low_mem  high_mem  avg_mem   avg_time  \
# 0      9.30                NaN     82.0    2633.0   1112.0   1779.746
# 1      9.46                NaN     79.0    4350.0   1388.4   1355.362
# 2    228.36                NaN    209.0   10376.0   3061.4   3822.140
# 3      1.46                NaN     82.0    4803.0   1544.2  10024.040
# 4      0.09                NaN     31.0   24699.0   9013.2  13639.468
#
#    high_time
# 0    8570.64
# 1    6296.49
# 2    8203.90
# 3   28426.36
# 4   46507.75

# %%
hwmcc20_results[['result', 'index']].groupby(['result']).count()
# Out:
#          index
# result
# sat         84
# unknown     43
# unsat      512

# %% [markdown]
# ## Compare Z3m and HWMCC20 modelcheckers

# %%
m: pd.DataFrame = pd.merge(df, hwmcc20_results, on='index')
m.head()
# Out:
#                                 index  SPACER_cex_depth  \
# 0    array-VexRiscv-regch0-15-p0.smt2               NaN
# 1    array-VexRiscv-regch0-15-p1.smt2               NaN
# 2    array-VexRiscv-regch0-20-p0.smt2               NaN
# 3  array-arbitrated_fifos_n2d8w8.smt2               NaN
# 4               array-array_swap.smt2               NaN
#
#    SPACER_expand_pob_undef  SPACER_inductive_level  SPACER_max_depth  \
# 0                      NaN                     NaN              15.0
# 1                      NaN                     NaN              10.0
# 2                      NaN                     NaN              15.0
# 3                      NaN                     NaN              22.0
# 4                      NaN                     NaN              67.0
#
#    SPACER_max_query_lvl  SPACER_num_active_lemmas  SPACER_num_ctp_blocked  \
# 0                  14.0                     464.0                    96.0
# 1                  10.0                     126.0                    13.0
# 2                  14.0                     561.0                    73.0
# 3                  21.0                     986.0                    20.0
# 4                  66.0                     248.0                    65.0
#
#    SPACER_num_invariants  SPACER_num_is_invariant  ...  low_real  high_real  \
# 0                  325.0                   1216.0  ...      9.40    2857.39
# 1                   79.0                    196.0  ...      9.59    3105.02
# 2                  384.0                   1406.0  ...    228.44    3600.10
# 3                   47.0                   8086.0  ...      0.74    3600.10
# 4                    NaN                  11721.0  ...      0.42    3600.10
#
#    avg_real  low_time  high_timeavg_time  low_mem  high_mem  avg_mem  \
# 0   586.858      9.30                NaN     82.0    2633.0   1112.0
# 1   641.160      9.46                NaN     79.0    4350.0   1388.4
# 2  1017.224    228.36                NaN    209.0   10376.0   3061.4
# 3  2874.864      1.46                NaN     82.0    4803.0   1544.2
# 4  2875.386      0.09                NaN     31.0   24699.0   9013.2
#
#     avg_time high_time
# 0   1779.746   8570.64
# 1   1355.362   6296.49
# 2   3822.140   8203.90
# 3  10024.040  28426.36
# 4  13639.468  46507.75
#
# [5 rows x 56 columns]

# %%
m[['status', 'index', 'result']].groupby(['status', 'result']).count()
# Out:
#                      index
# status      result
# (no status) sat          3
#             unknown      1
#             unsat        3
# sat         sat         13
#             unsat       10
# timeout     sat         54
#             unknown     20
#             unsat      173
# unknown     sat         14
#             unknown     21
#             unsat       56
# unsat       unknown      1
#             unsat      270

# %%
# {sat|uns|unk}_count: The number of model checkers
#                      that gives {sat|unsat|unknown}
query_columns: List[str] = ['index', 'status', 'result', 'time', 'memory',
                            'sat_count', 'uns_count', 'unk_count']
m.query('status == "sat" & result == "unsat"')[query_columns].sort_values('time')
# Out:
#                                     index status result  time  memory  \
# 443                          bv-miim.smt2    sat  unsat  0.02    6.57
# 582                      bv-stack-p2.smt2    sat  unsat  0.04    8.68
# 585    bv-vcegar_arrays_itc99_b12_p2.smt2    sat  unsat  0.04    7.75
# 554                      bv-rast-p00.smt2    sat  unsat  0.06    8.83
# 559                      bv-rast-p11.smt2    sat  unsat  0.06    8.32
# 424  bv-elevator.4.prop1-func-interl.smt2    sat  unsat  0.07    8.96
# 560                      bv-rast-p14.smt2    sat  unsat  0.09   13.41
# 562                      bv-rast-p17.smt2    sat  unsat  0.09   11.87
# 561                      bv-rast-p16.smt2    sat  unsat  0.10   13.41
# 444     bv-msmie.3.prop1-func-interl.smt2    sat  unsat  0.39   30.11
#
#      sat_count  uns_count  unk_count
# 443          0          9          1
# 582          0         10          1
# 585          0          1          1
# 554          0          6          1
# 559          0         10          1
# 424          0          9          1
# 560          0          2          1
# 562          0          1          1
# 561          0          4          1
# 444          0          5          1

# %% [markdown]
# For `bv-vcegar_arrays_itc99_b12_p2.smt2` and `bv-rast-p17.smt2`, only nmtip says unsat.

# %%
m.query('status == "unsat" & result == "sat"')[query_columns].sort_values('time')
# Out:
# Empty DataFrame
# Columns: [index, status, result, time, memory, sat_count, uns_count, unk_count]
# Index: []

# %%
m.query('status == "sat" & result == "unknown"')[query_columns].sort_values('time')
# Out:
# Empty DataFrame
# Columns: [index, status, result, time, memory, sat_count, uns_count, unk_count]
# Index: []

# %%
m.query('status == "unsat" & result == "unknown"')[query_columns].sort_values('time')
# Out:
#                              index status   result  time  memory  sat_count  \
# 168  array-simple-stack-pred1.smt2  unsat  unknown  0.05    8.05          0
#
#      uns_count  unk_count
# 168          0          1

# %%
plt.xlim(0, 3600)
plt.ylim(0, 3600)
g = sns.scatterplot(x='time', y='avg_real', hue='status', style='result', data=m)
sns.despine()
x = np.linspace(0, 900, 2)
g.plot(x, x)

# %% [markdown]
# ## BV

# %%
df['index'].str.startswith('bv')
df_bv: pd.DataFrame = df[df['index'].str.startswith('bv-')]
df_bv.head()
# Out:
#                                      index  SPACER_cex_depth  \
# 315          bv-VexRiscv-regch0-15-p0.smt2               NaN
# 316          bv-VexRiscv-regch0-20-p0.smt2               NaN
# 317          bv-VexRiscv-regch0-30-p1.smt2               NaN
# 318  bv-anderson.3.prop1-back-serstep.smt2               4.0
# 319  bv-arbitrated_top_n2_w128_d32_e0.smt2               NaN
#
#      SPACER_expand_pob_undef  SPACER_inductive_level  SPACER_max_depth  \
# 315                      NaN                     NaN              16.0
# 316                      NaN                     NaN              13.0
# 317                      NaN                     NaN              15.0
# 318                      NaN                     NaN               4.0
# 319                      NaN                     NaN              13.0
#
#      SPACER_max_query_lvl  SPACER_num_active_lemmas  SPACER_num_ctp_blocked  \
# 315                  15.0                     402.0                   191.0
# 316                  12.0                     423.0                    82.0
# 317                  14.0                     368.0                   129.0
# 318                   4.0                       8.0                     2.0
# 319                  12.0                     921.0                  1088.0
#
#      SPACER_num_invariants  SPACER_num_is_invariant  ...  time_spacer_ctp  \
# 315                  273.0                   1389.0  ...             1.65
# 316                  240.0                   1149.0  ...             1.39
# 317                  262.0                   1129.0  ...             1.47
# 318                    NaN                      9.0  ...              NaN
# 319                    1.0                   3943.0  ...             1.67
#
#      time_spacer_init_rules  time_spacer_init_rules_pt_init  time_spacer_mbp  \
# 315                    0.09                            0.08             6.94
# 316                    0.08                            0.08             7.91
# 317                    0.09                            0.08             6.23
# 318                    0.01                            0.00             0.01
# 319                    0.10                            0.10             2.36
#
#      time_spacer_solve  time_spacer_solve_propagate  time_spacer_solve_reach  \
# 315             651.54                        94.59                   556.90
# 316             795.27                        96.77                   698.47
# 317             516.26                        64.19                   452.02
# 318               7.15                         0.35                     6.78
# 319             769.77                       123.76                   645.97
#
#      time_spacer_solve_reach_children  time_spacer_solve_reach_gen_bool_ind  \
# 315                             10.14                                442.06
# 316                             11.32                                581.08
# 317                              9.56                                351.38
# 318                              0.01                                  4.09
# 319                              4.60                                555.54
#
#     time_spacer_solve_reach_is_reach
# 315                              NaN
# 316                              NaN
# 317                              NaN
# 318                             1.07
# 319                              NaN
#
# [5 rows x 39 columns]

# %%
# quick overview of solved/unsolved instances
df_bv[['status', 'index']].groupby(['status']).count()
# Out:
#              index
# status
# (no status)      2
# sat             23
# timeout        190
# unknown         15
# unsat           94

# %%
df_bv.query('status == "(no status)"')[['index', 'status']]
# Out:
#                                  index       status
# 425  bv-frogs.5.prop1-func-interl.smt2  (no status)
# 619         bv-zipcpu-pfcache-p24.smt2  (no status)

# %%
unknown_df_bv: pd.DataFrame = unknown_df[unknown_df['index'].str.startswith('bv-')]
unknown_df_bv.head()
# Out:
#                                      index   status  \
# 379                         bv-cal220.smt2  unknown
# 380                         bv-cal224.smt2  unknown
# 381                         bv-cal227.smt2  unknown
# 382                         bv-cal234.smt2  unknown
# 410  bv-dspfilters_fastfir_second-p07.smt2  unknown
#
#                                                                                        error
# 379                              (error "query failed: could not evaluate Boolean in model")
# 380                              (error "query failed: could not evaluate Boolean in model")
# 381                              (error "query failed: could not evaluate Boolean in model")
# 382                              (error "query failed: could not evaluate Boolean in model")
# 410  (error "query failed: rule validation failed when checking: (exists ((x!1 (_ BitVec 9))

# %%
unknown_df_bv.groupby('error')[['index']].agg(['first', 'count'])
# Out:
#                                                                                                                          index  \
#                                                                                                                          first
# error
# (error "query failed: could not evaluate Boolean in model")                                                     bv-cal220.smt2
# (error "query failed: rule validation failed when checking: (exists ((x!1 (_ BitVec 9))  bv-dspfilters_fastfir_second-p07.smt2
# (error "query failed: rule validation failed when checking: (exists ((x!1 Bool)                     bv-picorv32-check-p12.smt2
#
#
#                                                                                         count
# error
# (error "query failed: could not evaluate Boolean in model")                                11
# (error "query failed: rule validation failed when checking: (exists ((x!1 (_ BitVec 9))     3
# (error "query failed: rule validation failed when checking: (exists ((x!1 Bool)             1

# %%
hwmcc20_results_bv: pd.DataFrame = hwmcc20_results[hwmcc20_results['index'].str.startswith('bv-')]
hwmcc20_results_bv.head()
# Out:
#                                      index result  sat_count  uns_count  \
# 315          bv-VexRiscv-regch0-15-p0.smt2  unsat          0          8
# 316          bv-VexRiscv-regch0-20-p0.smt2  unsat          0          8
# 317          bv-VexRiscv-regch0-30-p1.smt2  unsat          0          6
# 318  bv-anderson.3.prop1-back-serstep.smt2    sat         11          0
# 319  bv-arbitrated_top_n2_w128_d32_e0.smt2    sat          5          0
#
#      unk_count  low_bound  high_bound  avg_bound  low_real  high_real  \
# 315          1         -1          -1  -1.000000      6.28    3600.11
# 316          1         -1          -1  -1.000000     52.68    3600.10
# 317          1         -1          -1  -1.000000    254.53    3600.11
# 318          0         -1           4   1.272727      0.03       3.13
# 319          0         -1          -1  -1.000000    591.76    3600.11
#
#         avg_real  low_time  high_timeavg_time  low_mem  high_mem  \
# 315   680.350909      6.19                NaN     91.0   16828.0
# 316   891.460909     52.59                NaN    161.0   31820.0
# 317  2101.825455    254.49                NaN    722.0  110681.0
# 318     0.594545      0.00                NaN      0.0    1753.0
# 319  2364.781818   1647.68                NaN    225.0   14825.0
#
#           avg_mem      avg_time  high_time
# 315   4166.545455   4722.890000   35991.59
# 316  10455.272727   6538.323636   35992.53
# 317  28088.818182  14905.270909   35903.45
# 318    309.363636      0.810909       4.54
# 319   5186.272727  15454.903636   44492.40

# %%
m_bv: pd.DataFrame = pd.merge(df_bv, hwmcc20_results_bv, on='index')
m_bv.head()
# Out:
#                                    index  SPACER_cex_depth  \
# 0          bv-VexRiscv-regch0-15-p0.smt2               NaN
# 1          bv-VexRiscv-regch0-20-p0.smt2               NaN
# 2          bv-VexRiscv-regch0-30-p1.smt2               NaN
# 3  bv-anderson.3.prop1-back-serstep.smt2               4.0
# 4  bv-arbitrated_top_n2_w128_d32_e0.smt2               NaN
#
#    SPACER_expand_pob_undef  SPACER_inductive_level  SPACER_max_depth  \
# 0                      NaN                     NaN              16.0
# 1                      NaN                     NaN              13.0
# 2                      NaN                     NaN              15.0
# 3                      NaN                     NaN               4.0
# 4                      NaN                     NaN              13.0
#
#    SPACER_max_query_lvl  SPACER_num_active_lemmas  SPACER_num_ctp_blocked  \
# 0                  15.0                     402.0                   191.0
# 1                  12.0                     423.0                    82.0
# 2                  14.0                     368.0                   129.0
# 3                   4.0                       8.0                     2.0
# 4                  12.0                     921.0                  1088.0
#
#    SPACER_num_invariants  SPACER_num_is_invariant  ...  low_real  high_real  \
# 0                  273.0                   1389.0  ...      6.28    3600.11
# 1                  240.0                   1149.0  ...     52.68    3600.10
# 2                  262.0                   1129.0  ...    254.53    3600.11
# 3                    NaN                      9.0  ...      0.03       3.13
# 4                    1.0                   3943.0  ...    591.76    3600.11
#
#       avg_real  low_time  high_timeavg_time  low_mem  high_mem       avg_mem  \
# 0   680.350909      6.19                NaN     91.0   16828.0   4166.545455
# 1   891.460909     52.59                NaN    161.0   31820.0  10455.272727
# 2  2101.825455    254.49                NaN    722.0  110681.0  28088.818182
# 3     0.594545      0.00                NaN      0.0    1753.0    309.363636
# 4  2364.781818   1647.68                NaN    225.0   14825.0   5186.272727
#
#        avg_time high_time
# 0   4722.890000  35991.59
# 1   6538.323636  35992.53
# 2  14905.270909  35903.45
# 3      0.810909      4.54
# 4  15454.903636  44492.40
#
# [5 rows x 56 columns]

# %%
m_bv[['status', 'index', 'result']].groupby(['status', 'result']).count()
# Out:
#                      index
# status      result
# (no status) unsat        2
# sat         sat         13
#             unsat       10
# timeout     sat         47
#             unknown     18
#             unsat      125
# unknown     sat          5
#             unknown      3
#             unsat        7
# unsat       unsat       94

# %%
plt.xlim(0, 3600)
plt.ylim(0, 3600)
g = sns.scatterplot(x='time', y='avg_real', hue='status', style='result', data=m_bv)
sns.despine()
x = np.linspace(0, 900, 2)
g.plot(x, x)

# %% [markdown]
# ## Array

# %%
df_array: pd.DataFrame = df[df['index'].str.startswith('array-')]
df_array.head()
# Out:
#                                 index  SPACER_cex_depth  \
# 0    array-VexRiscv-regch0-15-p0.smt2               NaN
# 1    array-VexRiscv-regch0-15-p1.smt2               NaN
# 2    array-VexRiscv-regch0-20-p0.smt2               NaN
# 3  array-arbitrated_fifos_n2d8w8.smt2               NaN
# 4               array-array_swap.smt2               NaN
#
#    SPACER_expand_pob_undef  SPACER_inductive_level  SPACER_max_depth  \
# 0                      NaN                     NaN              15.0
# 1                      NaN                     NaN              10.0
# 2                      NaN                     NaN              15.0
# 3                      NaN                     NaN              22.0
# 4                      NaN                     NaN              67.0
#
#    SPACER_max_query_lvl  SPACER_num_active_lemmas  SPACER_num_ctp_blocked  \
# 0                  14.0                     464.0                    96.0
# 1                  10.0                     126.0                    13.0
# 2                  14.0                     561.0                    73.0
# 3                  21.0                     986.0                    20.0
# 4                  66.0                     248.0                    65.0
#
#    SPACER_num_invariants  SPACER_num_is_invariant  ...  time_spacer_ctp  \
# 0                  325.0                   1216.0  ...             0.28
# 1                   79.0                    196.0  ...             0.01
# 2                  384.0                   1406.0  ...             0.76
# 3                   47.0                   8086.0  ...             0.00
# 4                    NaN                  11721.0  ...             0.00
#
#    time_spacer_init_rules  time_spacer_init_rules_pt_init  time_spacer_mbp  \
# 0                    0.06                            0.06             7.86
# 1                    0.06                            0.06             1.69
# 2                    0.06                            0.06             8.72
# 3                    0.01                            0.00             4.87
# 4                    0.00                             NaN             1.07
#
#    time_spacer_solve  time_spacer_solve_propagate  time_spacer_solve_reach  \
# 0             871.28                        83.78                   787.45
# 1              80.99                         3.91                    77.05
# 2             754.59                        76.39                   678.16
# 3             847.21                       289.88                   557.26
# 4             888.55                       544.79                   343.53
#
#    time_spacer_solve_reach_children  time_spacer_solve_reach_gen_bool_ind  \
# 0                             10.75                                653.80
# 1                              2.54                                 59.24
# 2                             12.29                                545.91
# 3                              7.25                                424.13
# 4                              3.97                                 22.48
#
#   time_spacer_solve_reach_is_reach
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
# [5 rows x 39 columns]

# %%
# quick overview of solved/unsolved instances
df_array[['status', 'index']].groupby('status').count()
# Out:
#              index
# status
# (no status)      5
# timeout         57
# unknown         76
# unsat          177

# %%
df_array.query('status == "(no status)"')[['index', 'status']]
# Out:
#                                    index       status
# 134           array-easy_zero_array.smt2  (no status)
# 135  array-marlann_compute_fail1-p0.smt2  (no status)
# 138  array-marlann_compute_fail2-p1.smt2  (no status)
# 139  array-marlann_compute_fail2-p2.smt2  (no status)
# 158     array-picorv32_mutBY_mem-p8.smt2  (no status)

# %%
unknown_df_array: pd.DataFrame = unknown_df[unknown_df['index'].str.startswith('array-')]
unknown_df_array.head()
# Out:
#                                             index   status  \
# 1                array-VexRiscv-regch0-15-p1.smt2  unknown
# 128  array-dblclockfft_butterfly_ck3_r2-p148.smt2  unknown
# 147              array-picorv32_mutAX_mem-p0.smt2  unknown
# 149              array-picorv32_mutAY_mem-p5.smt2  unknown
# 151              array-picorv32_mutAY_mem-p8.smt2  unknown
#
#                                                                                error
# 1                                                                            unknown
# 128  (error "query failed: rule validation failed when checking: (exists ((x!1 Bool)
# 147                                                                          unknown
# 149                      (error "query failed: could not evaluate Boolean in model")
# 151                      (error "query failed: could not evaluate Boolean in model")

# %%
unknown_df.groupby('error')[['index']].agg(['first', 'count'])
# Out:
#                                                                                                                                  index  \
#                                                                                                                                  first
# error
# (error "query failed: could not evaluate Boolean in model")                                           array-picorv32_mutAY_mem-p5.smt2
# (error "query failed: rule validation failed when checking: (exists ((x!1 (_ BitVec 32))              array-picorv32_mutCY_mem-p8.smt2
# (error "query failed: rule validation failed when checking: (exists ((x!1 (_ BitVec 9))          bv-dspfilters_fastfir_second-p07.smt2
# (error "query failed: rule validation failed when checking: (exists ((x!1 Bool)           array-dblclockfft_butterfly_ck3_r2-p148.smt2
# unknown                                                                                               array-VexRiscv-regch0-15-p1.smt2
#
#
#                                                                                          count
# error
# (error "query failed: could not evaluate Boolean in model")                                 71
# (error "query failed: rule validation failed when checking: (exists ((x!1 (_ BitVec 32))     1
# (error "query failed: rule validation failed when checking: (exists ((x!1 (_ BitVec 9))      3
# (error "query failed: rule validation failed when checking: (exists ((x!1 Bool)              2
# unknown                                                                                     14

# %%
hwmcc20_results_array: pd.DataFrame = hwmcc20_results[hwmcc20_results['index'].str.startswith('array-')]
hwmcc20_results_array.head()
# Out:
#                                 index   result  sat_count  uns_count  \
# 0    array-VexRiscv-regch0-15-p0.smt2    unsat          0          5
# 1    array-VexRiscv-regch0-15-p1.smt2    unsat          0          5
# 2    array-VexRiscv-regch0-20-p0.smt2    unsat          0          4
# 3  array-arbitrated_fifos_n2d8w8.smt2  unknown          0          0
# 4               array-array_swap.smt2  unknown          0          0
#
#    unk_count  low_bound  high_bound  avg_bound  low_real  high_real  avg_real  \
# 0          0         -1          -1       -1.0      9.40    2857.39   586.858
# 1          0         -1          -1       -1.0      9.59    3105.02   641.160
# 2          0         -1          -1       -1.0    228.44    3600.10  1017.224
# 3          2         -1          -1       -1.0      0.74    3600.10  2874.864
# 4          2         -1          -1       -1.0      0.42    3600.10  2875.386
#
#    low_time  high_timeavg_time  low_mem  high_mem  avg_mem   avg_time  \
# 0      9.30                NaN     82.0    2633.0   1112.0   1779.746
# 1      9.46                NaN     79.0    4350.0   1388.4   1355.362
# 2    228.36                NaN    209.0   10376.0   3061.4   3822.140
# 3      1.46                NaN     82.0    4803.0   1544.2  10024.040
# 4      0.09                NaN     31.0   24699.0   9013.2  13639.468
#
#    high_time
# 0    8570.64
# 1    6296.49
# 2    8203.90
# 3   28426.36
# 4   46507.75

# %%
m_array: pd.DataFrame = pd.merge(df_array, hwmcc20_results_array, on='index')
m_array.head()
# Out:
#                                 index  SPACER_cex_depth  \
# 0    array-VexRiscv-regch0-15-p0.smt2               NaN
# 1    array-VexRiscv-regch0-15-p1.smt2               NaN
# 2    array-VexRiscv-regch0-20-p0.smt2               NaN
# 3  array-arbitrated_fifos_n2d8w8.smt2               NaN
# 4               array-array_swap.smt2               NaN
#
#    SPACER_expand_pob_undef  SPACER_inductive_level  SPACER_max_depth  \
# 0                      NaN                     NaN              15.0
# 1                      NaN                     NaN              10.0
# 2                      NaN                     NaN              15.0
# 3                      NaN                     NaN              22.0
# 4                      NaN                     NaN              67.0
#
#    SPACER_max_query_lvl  SPACER_num_active_lemmas  SPACER_num_ctp_blocked  \
# 0                  14.0                     464.0                    96.0
# 1                  10.0                     126.0                    13.0
# 2                  14.0                     561.0                    73.0
# 3                  21.0                     986.0                    20.0
# 4                  66.0                     248.0                    65.0
#
#    SPACER_num_invariants  SPACER_num_is_invariant  ...  low_real  high_real  \
# 0                  325.0                   1216.0  ...      9.40    2857.39
# 1                   79.0                    196.0  ...      9.59    3105.02
# 2                  384.0                   1406.0  ...    228.44    3600.10
# 3                   47.0                   8086.0  ...      0.74    3600.10
# 4                    NaN                  11721.0  ...      0.42    3600.10
#
#    avg_real  low_time  high_timeavg_time  low_mem  high_mem  avg_mem  \
# 0   586.858      9.30                NaN     82.0    2633.0   1112.0
# 1   641.160      9.46                NaN     79.0    4350.0   1388.4
# 2  1017.224    228.36                NaN    209.0   10376.0   3061.4
# 3  2874.864      1.46                NaN     82.0    4803.0   1544.2
# 4  2875.386      0.09                NaN     31.0   24699.0   9013.2
#
#     avg_time high_time
# 0   1779.746   8570.64
# 1   1355.362   6296.49
# 2   3822.140   8203.90
# 3  10024.040  28426.36
# 4  13639.468  46507.75
#
# [5 rows x 56 columns]

# %%
m_array[['status', 'index', 'result']].groupby(['status', 'result']).count()
# Out:
#                      index
# status      result
# (no status) sat          3
#             unknown      1
#             unsat        1
# timeout     sat          7
#             unknown      2
#             unsat       48
# unknown     sat          9
#             unknown     18
#             unsat       49
# unsat       unknown      1
#             unsat      176

# %%
plt.xlim(0, 3600)
plt.ylim(0, 3600)
g = sns.scatterplot(x='time', y='avg_real', hue='status', style='result', data=m_array)
sns.despine()
x = np.linspace(0, 900, 2)
g.plot(x, x)
