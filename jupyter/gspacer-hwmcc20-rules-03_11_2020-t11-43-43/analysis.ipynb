# %% [markdown]
# # Analysis of Gspacer on HWMCC20 Rules
#
# - Start: Tuesday, November 3, 2020, 11:43:44 AM
# - End: Tuesday, November 3, 2020, 10:17:58 PM
# - Duration: 10 hours, 34 minutes, and 14 seconds
# - Number of benchmarks: 639
# - Timeout: 900 seconds
# - Branch: `gpsacer`
# - Arguments: `-st -v:1 -T:900 fp.xform.slice=true fp.xform.inline_linear=true fp.xform.inline_eager=true fp.xform.tail_simplifier_pve=true fp.engine=spacer fp.print_statistics=true fp.spacer.elim_aux=true fp.spacer.reach_dnf=true fp.spacer.iuc=1 fp.spacer.iuc.arith=1 fp.validate=true fp.spacer.ground_pobs=true fp.spacer.mbqi=false fp.spacer.iuc.print_farkas_stats=false fp.spacer.iuc.old_hyp_reducer=false fp.spacer.ctp=true fp.spacer.weak_abs=true fp.spacer.native_mbp=true fp.spacer.conjecture=true fp.spacer.global=true fp.spacer.concretize=true fp.spacer.use_sage=false fp.spacer.use_iuc=true`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from typing import Dict, List, Tuple


# noinspection PyUnresolvedReferences
pd.set_option('display.max_rows', None)
# noinspection PyUnresolvedReferences
pd.set_option('display.max_colwidth', None)

sns.set(style='ticks', palette='Set2')
# noinspection PyUnresolvedReferences
plt.rcParams['figure.figsize'] = (10, 10)

# %%
out_dir: str = '../../out/gspacer.hwmcc20-rules.lilla-my.03_11_2020-t11-43-43'

df: pd.DataFrame = pd.read_csv('out.csv')

df['status'].fillna(value='(no status)', inplace=True)

timeout = 900
df['time'].fillna(value=timeout, inplace=True)
df.loc[df['status'] == 'unknown', 'time'] = timeout

# show a snapshot of data for visual validation
df.head()
# Out:
#                                 index  SPACER_cex_depth  \
# 0    array-VexRiscv-regch0-15-p0.smt2               NaN
# 1    array-VexRiscv-regch0-15-p1.smt2               NaN
# 2    array-VexRiscv-regch0-20-p0.smt2               NaN
# 3  array-arbitrated_fifos_n2d8w8.smt2               NaN
# 4               array-array_swap.smt2               NaN
#
#    SPACER_cluster_out_of_gas  SPACER_conj  SPACER_conj_failed  \
# 0                        NaN          NaN                 NaN
# 1                        NaN          NaN                 NaN
# 2                        NaN          NaN                 NaN
# 3                       21.0          2.0                 2.0
# 4                        NaN          NaN                 NaN
#
#    SPACER_conj_success  SPACER_inductive_level  SPACER_max_depth  \
# 0                  NaN                     NaN               8.0
# 1                  NaN                     NaN               8.0
# 2                  NaN                     NaN               9.0
# 3                  NaN                     NaN              20.0
# 4                  NaN                     NaN               2.0
#
#    SPACER_max_query_lvl  SPACER_non_local_gen  ...  \
# 0                   8.0                   NaN  ...
# 1                   8.0                   NaN  ...
# 2                   9.0                   NaN  ...
# 3                  19.0                   2.0  ...
# 4                   1.0                   NaN  ...
#
#    time_spacer_init_rules_pt_init  time_spacer_mbp  time_spacer_solve  \
# 0                            0.06            13.96             124.64
# 1                            0.06             3.25              34.20
# 2                            0.06            15.49             153.23
# 3                            0.00            33.13             638.42
# 4                             NaN              NaN               0.01
#
#    time_spacer_solve_propagate  time_spacer_solve_reach  \
# 0                         0.86                   123.75
# 1                         3.00                    31.18
# 2                         8.65                   144.55
# 3                       195.09                   443.25
# 4                         0.00                     0.00
#
#    time_spacer_solve_reach_children  time_spacer_solve_reach_cluster  \
# 0                             15.31                             0.69
# 1                              3.83                             0.04
# 2                             16.77                             0.31
# 3                             29.43                             7.32
# 4                               NaN                              NaN
#
#    time_spacer_solve_reach_gen_bool_ind  time_spacer_solve_reach_gen_global  \
# 0                                 86.06                                 NaN
# 1                                 20.25                                 NaN
# 2                                103.92                                 NaN
# 3                                290.13                                4.88
# 4                                   NaN                                 NaN
#
#    time_spacer_solve_reach_is_reach
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                              1.59
# 4                               NaN
#
# [5 rows x 50 columns]

# %%
# quick overview of solved/unsolved instances
df[['status', 'index']].groupby('status').count()
# Out:
#              index
# status
# (no status)      6
# sat             22
# timeout        301
# unknown         34
# unsat          276

# %%
df.query('status == "(no status)"')[['index', 'status']]
# Out:
#                                             index       status
# 92   array-dblclockfft_butterfly_ck3_r0-p051.smt2  (no status)
# 105  array-dblclockfft_butterfly_ck3_r1-p049.smt2  (no status)
# 135           array-marlann_compute_fail1-p0.smt2  (no status)
# 138           array-marlann_compute_fail2-p1.smt2  (no status)
# 139           array-marlann_compute_fail2-p2.smt2  (no status)
# 634           bv-zipversa_composecrc_prf-p10.smt2  (no status)

# %%
# Find unknown results. Usually means that something went wrong, not just timeout.
unknown_df: pd.DataFrame = df.query('status == "unknown"')[['index', 'status']]

def get_error(index: str) -> str:
    with open(os.path.join(out_dir, index)) as f:
        return f.readline().strip()

unknown_df['error'] = unknown_df['index'].apply(get_error)
unknown_df.sort_values('error').head()
# Out:
#                                 index   status  \
# 2    array-VexRiscv-regch0-20-p0.smt2  unknown
# 173      array-zipcpu-zipmmu-p28.smt2  unknown
# 172      array-zipcpu-zipmmu-p26.smt2  unknown
# 0    array-VexRiscv-regch0-15-p0.smt2  unknown
# 1    array-VexRiscv-regch0-15-p1.smt2  unknown
#
#                                                                                                                                                  error
# 2    (error "query failed: Argument #b00011 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")
# 173     (error "query failed: Argument #b11 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 20) (_ BitVec 20)) (_ BitVec 20))")
# 172     (error "query failed: Argument #b11 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 20) (_ BitVec 20)) (_ BitVec 20))")
# 0    (error "query failed: Argument #b11111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")
# 1    (error "query failed: Argument #b11111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")

# %%
unknown_df.groupby('error')[['index']].agg(['first', 'count'])
# Out:
#                                                                                                                                                                                                index  \
#                                                                                                                                                                                                first
# error
# (error "query failed: Argument #b00011 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")                   array-VexRiscv-regch0-20-p0.smt2
# (error "query failed: Argument #b11 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 20) (_ BitVec 20)) (_ BitVec 20))")                          array-zipcpu-zipmmu-p26.smt2
# (error "query failed: Argument #b11111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")                   array-VexRiscv-regch0-15-p0.smt2
# (error "query failed: Argument #b1111111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")                         array-array_swap.smt2
# (error "query failed: operator is applied to arguments of the wrong sort")                                                                              array-dblclockfft_butterfly_ck3_r2-p042.smt2
# (error "query failed: rule validation failed when checking: (and (not false))")                                                                                           bv-picorv32-pcregs-p0.smt2
# (error "query failed: rule validation failed when checking: (exists ((x!1 Bool)                                                                            array-dblclockfft_butterfly_ck1-p063.smt2
#
#
#                                                                                                                                                        count
# error
# (error "query failed: Argument #b00011 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")          1
# (error "query failed: Argument #b11 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 20) (_ BitVec 20)) (_ BitVec 20))")             2
# (error "query failed: Argument #b11111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")          3
# (error "query failed: Argument #b1111111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")     2
# (error "query failed: operator is applied to arguments of the wrong sort")                                                                                 1
# (error "query failed: rule validation failed when checking: (and (not false))")                                                                            2
# (error "query failed: rule validation failed when checking: (exists ((x!1 Bool)                                                                           23

# %%
df_ratio: pd.DataFrame = df.assign(ratio=df['time_pool_solver_smt_total'] / df['time_spacer_solve'])
df_ratio[(df_ratio['ratio'] < 0.5) & (df_ratio['time_spacer_solve'] > 10)]\
    [['index', 'time_pool_solver_smt_total', 'time_spacer_solve', 'ratio']]\
    .sort_values('ratio', ascending=True)
# Out:
#                                          index  time_pool_solver_smt_total  \
# 407      bv-dspfilters_fastfir_second-p04.smt2                        1.57
# 11   array-dblclockfft_butterfly_ck1-p068.smt2                       50.92
# 394                              bv-cal97.smt2                      139.10
# 17   array-dblclockfft_butterfly_ck1-p117.smt2                       79.92
# 420      bv-dspfilters_fastfir_second-p26.smt2                      153.81
# 43   array-dblclockfft_butterfly_ck1-p343.smt2                       12.36
# 34   array-dblclockfft_butterfly_ck1-p269.smt2                       13.38
# 419      bv-dspfilters_fastfir_second-p25.smt2                       80.69
# 45   array-dblclockfft_butterfly_ck1-p348.smt2                        3.76
# 21   array-dblclockfft_butterfly_ck1-p167.smt2                       15.86
# 51   array-dblclockfft_butterfly_ck1-p375.smt2                        4.04
# 14   array-dblclockfft_butterfly_ck1-p078.smt2                        6.99
# 58   array-dblclockfft_butterfly_ck1-p436.smt2                       11.21
# 57   array-dblclockfft_butterfly_ck1-p434.smt2                        4.68
# 411      bv-dspfilters_fastfir_second-p09.smt2                       67.31
# 55   array-dblclockfft_butterfly_ck1-p428.smt2                        5.46
# 52   array-dblclockfft_butterfly_ck1-p386.smt2                       44.20
# 583                    bv-vcegar_QF_BV_ar.smt2                        3.87
# 295        array-zipcpu_zipcpu_piped-p389.smt2                      109.67
# 10   array-dblclockfft_butterfly_ck1-p063.smt2                       43.99
# 44   array-dblclockfft_butterfly_ck1-p346.smt2                       34.44
# 42   array-dblclockfft_butterfly_ck1-p341.smt2                       23.50
# 179       array-zipcpu_zipcpu_dcache-p028.smt2                      278.97
# 26   array-dblclockfft_butterfly_ck1-p212.smt2                        4.91
# 218       array-zipcpu_zipcpu_dcache-p407.smt2                       39.56
# 183       array-zipcpu_zipcpu_dcache-p068.smt2                      304.87
# 409      bv-dspfilters_fastfir_second-p06.smt2                       78.82
# 371                             bv-cal176.smt2                      285.70
# 6    array-dblclockfft_butterfly_ck1-p015.smt2                        9.63
# 48   array-dblclockfft_butterfly_ck1-p354.smt2                        5.87
# 36   array-dblclockfft_butterfly_ck1-p285.smt2                       14.10
# 50   array-dblclockfft_butterfly_ck1-p372.smt2                       49.59
# 214       array-zipcpu_zipcpu_dcache-p360.smt2                      174.89
# 40   array-dblclockfft_butterfly_ck1-p310.smt2                        5.41
# 206       array-zipcpu_zipcpu_dcache-p238.smt2                       30.47
# 196       array-zipcpu_zipcpu_dcache-p159.smt2                       16.80
# 238       array-zipcpu_zipcpu_dcache-p582.smt2                      137.10
# 47   array-dblclockfft_butterfly_ck1-p352.smt2                       27.88
# 302        array-zipcpu_zipcpu_piped-p466.smt2                      335.08
# 198       array-zipcpu_zipcpu_dcache-p179.smt2                       93.06
# 187       array-zipcpu_zipcpu_dcache-p082.smt2                      108.74
# 205       array-zipcpu_zipcpu_dcache-p237.smt2                       71.92
# 25   array-dblclockfft_butterfly_ck1-p200.smt2                       11.70
# 363                             bv-cal140.smt2                        7.19
# 364                             bv-cal142.smt2                        7.16
# 474            bv-picorv32_mutBY_nomem-p6.smt2                       82.64
# 23   array-dblclockfft_butterfly_ck1-p191.smt2                      177.65
# 467            bv-picorv32_mutAY_nomem-p6.smt2                       86.42
# 41   array-dblclockfft_butterfly_ck1-p333.smt2                       32.97
# 358                             bv-cal119.smt2                        5.78
# 473            bv-picorv32_mutBY_nomem-p4.smt2                       83.99
# 195       array-zipcpu_zipcpu_dcache-p158.smt2                      147.98
# 410      bv-dspfilters_fastfir_second-p07.smt2                      111.14
# 193       array-zipcpu_zipcpu_dcache-p138.smt2                      356.35
# 192       array-zipcpu_zipcpu_dcache-p126.smt2                      218.19
# 262        array-zipcpu_zipcpu_piped-p162.smt2                      399.98
# 360                             bv-cal123.smt2                        6.11
# 475            bv-picorv32_mutBY_nomem-p7.smt2                      106.12
# 232       array-zipcpu_zipcpu_dcache-p550.smt2                      328.31
# 354                             bv-cal107.smt2                       52.48
# 395                              bv-cal99.smt2                       11.58
# 365                             bv-cal143.smt2                        9.41
# 16   array-dblclockfft_butterfly_ck1-p106.smt2                        5.07
# 439        bv-marlann_compute_cp_fail1-p2.smt2                       49.07
# 194       array-zipcpu_zipcpu_dcache-p141.smt2                      355.87
#
#      time_spacer_solve     ratio
# 407             810.30  0.001938
# 11              740.80  0.068737
# 394             862.77  0.161225
# 17              465.06  0.171849
# 420             888.76  0.173061
# 43               60.73  0.203524
# 34               56.58  0.236479
# 419             337.71  0.238933
# 45               15.28  0.246073
# 21               64.21  0.247002
# 51               16.02  0.252185
# 14               26.65  0.262289
# 58               39.33  0.285024
# 57               16.01  0.292317
# 411             227.26  0.296181
# 55               18.16  0.300661
# 52              145.77  0.303217
# 583              12.76  0.303292
# 295             359.38  0.305164
# 10              141.17  0.311610
# 44              110.47  0.311759
# 42               73.63  0.319163
# 179             853.98  0.326670
# 26               15.02  0.326897
# 218             118.07  0.335055
# 183             898.09  0.339465
# 409             229.76  0.343054
# 371             818.56  0.349028
# 6                26.99  0.356799
# 48               16.05  0.365732
# 36               37.39  0.377106
# 50              130.38  0.380350
# 214             459.69  0.380452
# 40               14.06  0.384780
# 206              79.11  0.385160
# 196              43.39  0.387186
# 238             344.47  0.398003
# 47               69.65  0.400287
# 302             833.56  0.401987
# 198             229.52  0.405455
# 187             264.58  0.410991
# 205             174.67  0.411748
# 25               27.65  0.423146
# 363              16.94  0.424439
# 364              16.78  0.426698
# 474             191.93  0.430574
# 23              408.10  0.435310
# 467             195.81  0.441346
# 41               74.66  0.441602
# 358              12.94  0.446677
# 473             187.33  0.448353
# 195             323.70  0.457152
# 410             239.90  0.463276
# 193             766.15  0.465118
# 192             467.16  0.467056
# 262             856.07  0.467228
# 360              13.02  0.469278
# 475             225.75  0.470078
# 232             695.25  0.472219
# 354             110.17  0.476355
# 395              24.05  0.481497
# 365              19.46  0.483556
# 16               10.34  0.490329
# 439              99.82  0.491585
# 194             712.26  0.499635

# %%
max_expand_time_line_no_memo: Dict[str, int] = {}
def get_max_expand_time(index: str) -> float:
    max_expand_time: float = 0
    max_expand_line: int = 0
    multi_line: bool = False
    with open(os.path.join(out_dir, index + '.err')) as f:
        for i, line in enumerate(f):
            tokens: List[str] = line.split()
            if len(tokens) > 2:
                first: str = tokens[0]
                second_last: str = tokens[-2]
                last: str = tokens[-1]
                if multi_line:
                    if len(second_last) == 1 and not last.endswith('.') and last.replace('.', '', 1).isdigit():
                        multi_line = False
                        expand_time: float = float(last)
                        if expand_time > max_expand_time:
                            max_expand_time = expand_time
                            max_expand_line = i + 1
                elif first == 'expand:':
                    if len(second_last) == 1 and not last.endswith('.') and last.replace('.', '', 1).isdigit():
                        expand_time: float = float(last)
                        if expand_time > max_expand_time:
                            max_expand_time = expand_time
                            max_expand_line = i + 1
                    else:
                        multi_line = True
    max_expand_time_line_no_memo[index] = max_expand_line
    return max_expand_time

def get_max_expand_time_line_no(index: str) -> int:
    return max_expand_time_line_no_memo[index]

df_max_expand_time: pd.DataFrame = df.assign(max_expand_time=df['index'].apply(get_max_expand_time),
                                             max_expand_time_line_no=df['index'].apply(get_max_expand_time_line_no))
df_max_expand_time[df_max_expand_time['max_expand_time'] > 5]\
    [['index', 'max_expand_time', 'max_expand_time_line_no']]\
    .sort_values('max_expand_time', ascending=False)
# Out:
#                                             index  max_expand_time  \
# 407         bv-dspfilters_fastfir_second-p04.smt2           808.54
# 394                                 bv-cal97.smt2           649.24
# 371                                bv-cal176.smt2           467.60
# 151              array-picorv32_mutAY_mem-p8.smt2           414.41
# 418         bv-dspfilters_fastfir_second-p22.smt2           305.79
# 11      array-dblclockfft_butterfly_ck1-p068.smt2           280.71
# 411         bv-dspfilters_fastfir_second-p09.smt2           271.81
# 333         bv-arbitrated_top_n4_w128_d16_e0.smt2           249.76
# 17      array-dblclockfft_butterfly_ck1-p117.smt2           237.35
# 412         bv-dspfilters_fastfir_second-p10.smt2           216.83
# 355                                bv-cal112.smt2           199.72
# 118  array-dblclockfft_butterfly_ck3_r2-p029.smt2           145.65
# 420         bv-dspfilters_fastfir_second-p26.smt2           127.60
# 351                        bv-buggy_ridecore.smt2           123.72
# 354                                bv-cal107.smt2           109.61
# 352                                bv-cal102.smt2           106.34
# 569        bv-shift_register_top_w128_d64_e0.smt2           103.44
# 566                              bv-ridecore.smt2            94.50
# 353                                bv-cal106.smt2            82.91
# 410         bv-dspfilters_fastfir_second-p07.smt2            81.60
# 179          array-zipcpu_zipcpu_dcache-p028.smt2            78.58
# 193          array-zipcpu_zipcpu_dcache-p138.smt2            73.60
# 381                                bv-cal227.smt2            65.19
# 378                                bv-cal210.smt2            63.87
# 23      array-dblclockfft_butterfly_ck1-p191.smt2            60.14
# 114  array-dblclockfft_butterfly_ck3_r1-p159.smt2            57.38
# 232          array-zipcpu_zipcpu_dcache-p550.smt2            53.35
# 80   array-dblclockfft_butterfly_ck2_r0-p173.smt2            52.99
# 448                                  bv-mul7.smt2            49.90
# 608                   bv-zipcpu-busdelay-p15.smt2            49.42
# 214          array-zipcpu_zipcpu_dcache-p360.smt2            46.95
# 568        bv-shift_register_top_w128_d16_e0.smt2            42.85
# 149              array-picorv32_mutAY_mem-p5.smt2            42.07
# 199          array-zipcpu_zipcpu_dcache-p192.smt2            41.75
# 192          array-zipcpu_zipcpu_dcache-p126.smt2            40.90
# 262           array-zipcpu_zipcpu_piped-p162.smt2            40.79
# 159              array-picorv32_mutCX_mem-p0.smt2            40.48
# 258           array-zipcpu_zipcpu_piped-p146.smt2            38.91
# 329         bv-arbitrated_top_n3_w64_d128_e0.smt2            36.50
# 480             bv-ponylink-slaveTXlen-unsat.smt2            35.47
# 164              array-picorv32_mutCY_mem-p8.smt2            32.88
# 341         bv-arbitrated_top_n5_w128_d64_e0.smt2            32.71
# 575        bv-shift_register_top_w32_d128_e0.smt2            31.62
# 396     bv-circular_pointer_top_w128_d128_e0.smt2            29.37
# 130  array-dblclockfft_butterfly_ck3_r2-p154.smt2            25.72
# 52      array-dblclockfft_butterfly_ck1-p386.smt2            25.68
# 404      bv-circular_pointer_top_w64_d128_e0.smt2            24.70
# 361                                bv-cal125.smt2            24.57
# 166             array-ridecore_array_unknown.smt2            23.69
# 109  array-dblclockfft_butterfly_ck3_r1-p119.smt2            23.63
# 398       bv-circular_pointer_top_w128_d8_e0.smt2            22.85
# 397      bv-circular_pointer_top_w128_d64_e0.smt2            21.98
# 360                                bv-cal123.smt2            20.94
# 205          array-zipcpu_zipcpu_dcache-p237.smt2            20.84
# 19      array-dblclockfft_butterfly_ck1-p147.smt2            20.83
# 447                                  bv-mul3.smt2            20.24
# 319         bv-arbitrated_top_n2_w128_d32_e0.smt2            20.05
# 167              array-ridecore_array_unsafe.smt2            19.80
# 320         bv-arbitrated_top_n2_w128_d64_e0.smt2            19.41
# 152              array-picorv32_mutBX_mem-p1.smt2            19.27
# 477               bv-picorv32_mutCX_nomem-p8.smt2            18.79
# 425             bv-frogs.5.prop1-func-interl.smt2            18.57
# 226          array-zipcpu_zipcpu_dcache-p506.smt2            17.54
# 366                                bv-cal149.smt2            16.84
# 218          array-zipcpu_zipcpu_dcache-p407.smt2            16.59
# 228          array-zipcpu_zipcpu_dcache-p519.smt2            16.42
# 147              array-picorv32_mutAX_mem-p0.smt2            16.10
# 342          bv-arbitrated_top_n5_w128_d8_e0.smt2            15.89
# 571         bv-shift_register_top_w16_d16_e0.smt2            14.96
# 357                                bv-cal118.smt2            14.91
# 358                                bv-cal119.smt2            14.90
# 356                                bv-cal117.smt2            14.77
# 238          array-zipcpu_zipcpu_dcache-p582.smt2            14.71
# 88   array-dblclockfft_butterfly_ck3_r0-p021.smt2            13.86
# 339          bv-arbitrated_top_n4_w64_d32_e0.smt2            13.57
# 330          bv-arbitrated_top_n3_w64_d64_e0.smt2            13.43
# 364                                bv-cal142.smt2            13.23
# 419         bv-dspfilters_fastfir_second-p25.smt2            12.64
# 67   array-dblclockfft_butterfly_ck2_r0-p096.smt2            12.40
# 295           array-zipcpu_zipcpu_piped-p389.smt2            12.26
# 263           array-zipcpu_zipcpu_piped-p163.smt2            12.24
# 154              array-picorv32_mutBX_mem-p5.smt2            12.23
# 156              array-picorv32_mutBX_mem-p7.smt2            12.23
# 438             bv-krebs.3.prop1-func-interl.smt2            11.89
# 612                   bv-zipcpu-busdelay-p46.smt2            11.75
# 372                                bv-cal192.smt2            11.67
# 305           array-zipcpu_zipcpu_piped-p476.smt2            11.20
# 315                 bv-VexRiscv-regch0-15-p0.smt2            11.15
# 165          array-ponylink-slaveTXlen-unsat.smt2            11.00
# 302           array-zipcpu_zipcpu_piped-p466.smt2            10.97
# 104  array-dblclockfft_butterfly_ck3_r1-p047.smt2            10.96
# 453     bv-pgm_protocol.7.prop1-back-serstep.smt2            10.84
# 462               bv-picorv32_mutAX_nomem-p0.smt2            10.65
# 403       bv-circular_pointer_top_w32_d32_e0.smt2            10.62
# 344          bv-arbitrated_top_n5_w64_d16_e0.smt2            10.55
# 321          bv-arbitrated_top_n2_w64_d64_e0.smt2            10.54
# 203          array-zipcpu_zipcpu_dcache-p229.smt2            10.53
# 593                   bv-vgasim_imgfifo-p088.smt2            10.43
# 395                                 bv-cal99.smt2            10.30
# 297           array-zipcpu_zipcpu_piped-p399.smt2            10.29
# 334         bv-arbitrated_top_n4_w128_d64_e0.smt2            10.13
# 626                     bv-zipcpu-zipmmu-p26.smt2             9.80
# 380                                bv-cal224.smt2             9.49
# 350             bv-brp2.6.prop3-back-serstep.smt2             9.39
# 99   array-dblclockfft_butterfly_ck3_r0-p111.smt2             8.88
# 362                                bv-cal129.smt2             8.87
# 133  array-dblclockfft_butterfly_ck3_r2-p173.smt2             8.84
# 393                                 bv-cal90.smt2             8.73
# 30      array-dblclockfft_butterfly_ck1-p255.smt2             8.45
# 349             bv-brp2.3.prop1-back-serstep.smt2             8.42
# 374                                bv-cal201.smt2             8.14
# 236          array-zipcpu_zipcpu_dcache-p578.smt2             8.13
# 73   array-dblclockfft_butterfly_ck2_r0-p129.smt2             8.13
# 70   array-dblclockfft_butterfly_ck2_r0-p101.smt2             8.01
# 597                   bv-vgasim_imgfifo-p105.smt2             8.01
# 618                    bv-zipcpu-pfcache-p22.smt2             8.01
# 113  array-dblclockfft_butterfly_ck3_r1-p157.smt2             7.92
# 464               bv-picorv32_mutAX_nomem-p5.smt2             7.83
# 108  array-dblclockfft_butterfly_ck3_r1-p086.smt2             7.81
# 81   array-dblclockfft_butterfly_ck2_r0-p185.smt2             7.69
# 570        bv-shift_register_top_w16_d128_e0.smt2             7.61
# 619                    bv-zipcpu-pfcache-p24.smt2             7.60
# 180          array-zipcpu_zipcpu_dcache-p034.smt2             7.57
# 66   array-dblclockfft_butterfly_ck2_r0-p095.smt2             7.42
# 409         bv-dspfilters_fastfir_second-p06.smt2             7.40
# 98   array-dblclockfft_butterfly_ck3_r0-p090.smt2             7.38
# 359                                bv-cal122.smt2             7.27
# 365                                bv-cal143.smt2             7.24
# 317                 bv-VexRiscv-regch0-30-p1.smt2             7.14
# 600                   bv-vgasim_imgfifo-p111.smt2             7.13
# 573         bv-shift_register_top_w16_d64_e0.smt2             7.07
# 363                                bv-cal140.smt2             7.07
# 347           bv-blocks.4.prop1-back-serstep.smt2             7.06
# 415         bv-dspfilters_fastfir_second-p16.smt2             6.93
# 230          array-zipcpu_zipcpu_dcache-p527.smt2             6.91
# 348              bv-brp2.2.prop1-func-interl.smt2             6.88
# 285           array-zipcpu_zipcpu_piped-p327.smt2             6.81
# 577          bv-shift_register_top_w32_d8_e0.smt2             6.81
# 96   array-dblclockfft_butterfly_ck3_r0-p066.smt2             6.80
# 163              array-picorv32_mutCY_mem-p3.smt2             6.75
# 158              array-picorv32_mutBY_mem-p8.smt2             6.74
# 442              bv-mcs.3.prop1-back-serstep.smt2             6.67
# 208          array-zipcpu_zipcpu_dcache-p286.smt2             6.63
# 157              array-picorv32_mutBY_mem-p4.smt2             6.54
# 476               bv-picorv32_mutCX_nomem-p0.smt2             6.53
# 399      bv-circular_pointer_top_w16_d128_e0.smt2             6.53
# 153              array-picorv32_mutBX_mem-p2.smt2             6.52
# 240          array-zipcpu_zipcpu_dcache-p595.smt2             6.52
# 28      array-dblclockfft_butterfly_ck1-p222.smt2             6.51
# 291           array-zipcpu_zipcpu_piped-p351.smt2             6.49
# 463               bv-picorv32_mutAX_nomem-p2.smt2             6.42
# 402       bv-circular_pointer_top_w32_d16_e0.smt2             6.36
# 77   array-dblclockfft_butterfly_ck2_r0-p159.smt2             6.33
# 160              array-picorv32_mutCX_mem-p3.smt2             6.21
# 155              array-picorv32_mutBX_mem-p6.smt2             6.12
# 615                    bv-zipcpu-pfcache-p02.smt2             6.12
# 249           array-zipcpu_zipcpu_piped-p081.smt2             6.11
# 91   array-dblclockfft_butterfly_ck3_r0-p048.smt2             6.06
# 468               bv-picorv32_mutBX_nomem-p0.smt2             6.03
# 586                   bv-vgasim_imgfifo-p036.smt2             6.01
# 591                   bv-vgasim_imgfifo-p075.smt2             5.96
# 222          array-zipcpu_zipcpu_dcache-p440.smt2             5.94
# 212          array-zipcpu_zipcpu_dcache-p340.smt2             5.93
# 470               bv-picorv32_mutBX_nomem-p8.smt2             5.90
# 94   array-dblclockfft_butterfly_ck3_r0-p053.smt2             5.88
# 316                 bv-VexRiscv-regch0-20-p0.smt2             5.88
# 224          array-zipcpu_zipcpu_dcache-p476.smt2             5.87
# 217          array-zipcpu_zipcpu_dcache-p388.smt2             5.79
# 375                                bv-cal206.smt2             5.64
# 327          bv-arbitrated_top_n3_w16_d32_e0.smt2             5.62
# 161              array-picorv32_mutCX_mem-p7.smt2             5.57
# 592                   bv-vgasim_imgfifo-p082.smt2             5.56
# 614                    bv-zipcpu-pfcache-p01.smt2             5.52
# 459                    bv-picorv32-check-p22.smt2             5.44
# 590                   bv-vgasim_imgfifo-p070.smt2             5.41
# 452      bv-pgm_protocol.3.prop5-func-interl.smt2             5.38
# 106  array-dblclockfft_butterfly_ck3_r1-p054.smt2             5.32
# 162              array-picorv32_mutCY_mem-p1.smt2             5.30
# 269           array-zipcpu_zipcpu_piped-p211.smt2             5.26
# 337          bv-arbitrated_top_n4_w16_d64_e0.smt2             5.26
# 373                                  bv-cal2.smt2             5.23
# 90   array-dblclockfft_butterfly_ck3_r0-p042.smt2             5.23
# 72   array-dblclockfft_butterfly_ck2_r0-p106.smt2             5.15
# 303           array-zipcpu_zipcpu_piped-p472.smt2             5.13
# 326         bv-arbitrated_top_n3_w16_d128_e0.smt2             5.01
#
#      max_expand_time_line_no
# 407                     3099
# 394                     1323
# 371                     4910
# 151                    11154
# 418                    23328
# 11                     12270
# 411                    10104
# 333                    13419
# 17                     10253
# 412                    24417
# 355                      620
# 118                     2632
# 420                      966
# 351                      226
# 354                      404
# 352                      565
# 569                     1450
# 566                      211
# 353                      399
# 410                     6166
# 179                    14275
# 193                    10489
# 381                     1083
# 378                      439
# 23                      9194
# 114                     6931
# 232                    15981
# 80                      6924
# 448                      193
# 608                     2697
# 214                     8126
# 568                      730
# 149                    30945
# 199                    13757
# 192                     6713
# 262                    15151
# 159                    10048
# 258                     5217
# 329                      504
# 480                    13521
# 164                    12248
# 341                     2861
# 575                      985
# 396                      873
# 130                      744
# 52                      4133
# 404                     2354
# 361                     9230
# 166                     1204
# 109                     5630
# 398                     2516
# 397                     1085
# 360                     7960
# 205                     2267
# 19                     10234
# 447                      237
# 319                     4708
# 167                      165
# 320                     5166
# 152                     9374
# 477                     7286
# 425                      879
# 226                     8412
# 366                     6929
# 218                     7953
# 228                    13427
# 147                     9485
# 342                    12207
# 571                     3662
# 357                    13454
# 358                     9537
# 356                    12919
# 238                    15419
# 88                      6233
# 339                    18092
# 330                     5339
# 364                      229
# 419                     8084
# 67                      2561
# 295                     3398
# 263                     4995
# 154                     2490
# 156                     8045
# 438                     3211
# 612                     4783
# 372                      233
# 305                     3325
# 315                    14040
# 165                    14384
# 302                    28751
# 104                     8029
# 453                     1908
# 462                     1508
# 403                     3550
# 344                    14626
# 321                     4784
# 203                    13165
# 593                     2049
# 395                     8457
# 297                     1918
# 334                     5873
# 626                    11509
# 380                     1362
# 350                     4094
# 99                      4439
# 362                     4378
# 133                     1853
# 393                     8643
# 30                     13215
# 349                     2954
# 374                      214
# 236                     3053
# 73                      6993
# 70                      7873
# 597                     2880
# 618                     8515
# 113                     1187
# 464                     7327
# 108                     6365
# 81                      4108
# 570                     3244
# 619                     8828
# 180                     3937
# 66                      8053
# 409                    15992
# 98                      6824
# 359                      756
# 365                      267
# 317                    12489
# 600                     2418
# 573                     4011
# 363                      171
# 347                     2050
# 415                      317
# 230                    17258
# 348                     5483
# 285                    14090
# 577                     2667
# 96                      5961
# 163                    22081
# 158                    25502
# 442                     2433
# 208                    17806
# 157                    25520
# 476                     6853
# 399                     2199
# 153                    13945
# 240                     8355
# 28                      5095
# 291                     4550
# 463                     4838
# 402                     4389
# 77                      3887
# 160                     1699
# 155                     2300
# 615                     8139
# 249                    14613
# 91                      3535
# 468                     3353
# 586                     3238
# 591                     2735
# 222                     5575
# 212                    14794
# 470                     1340
# 94                      4831
# 316                     8760
# 224                     6853
# 217                     7612
# 375                      212
# 327                    19636
# 161                     3624
# 592                     2874
# 614                     7690
# 459                     5721
# 590                     2792
# 452                     4468
# 106                     2272
# 162                    27051
# 269                    12719
# 337                    17554
# 373                      610
# 90                      6491
# 72                       851
# 303                     4580
# 326                      300

# %% [markdown]
# ## HWMCC20 modelcheckers

# %%
pd.read_csv('http://fmv.jku.at/hwmcc20/hwmcc20-combined-all.txt', delim_whitespace=True)
# Out:
#          cnt   ok  sat  uns  dis  fld   to  mo  unk    real     time    space  \
# avr      639  547   66  481    0   92    0   0   92   71456  1049649  2282407
# nuxmv    639  500   50  450    0  139  139   0    0   99664   339693   505974
# pono     639  386   58  328    0  253  219  22   12   63789   288937   596666
# cosa2    639  373   58  315    0  266  252   1   13  136153   537672   585138
# btormc   639  333   59  274    0  306  305   0    1   53822    53797    47550
# abc      324  262   56  206    0   62   62   0    0   36505   429078   344728
# abc17    324  262   55  207    0   62   62   0    0   39465   470045   352773
# pdtrav   324  245   45  200    0   79   76   0    3   74891   429930   713508
# avy      324  236   40  196    0   88   88   0    0   44055   437528   426064
# nmtip    324  210   17  193   26   88   88   0    0   24949    24933    17119
# camical  324   43   43    0    0  281  142   0  139   30048    30046     9821
#
#            max  best  uniq
# avr      49141   100    23
# nuxmv     6898    12     2
# pono     77761    38     1
# cosa2    14623    17     0
# btormc    2565   208     2
# abc      31293    29     1
# abc17    31820    10     1
# pdtrav   30090     8     2
# avy      14949    25     0
# nmtip     3117   142    13
# camical    945     8     0

# %%
# The values of the result column are unknown if all model checkers
# gives unknown, or if the number of model checkers that says sat
# and the number of those that say unsat tie. Otherwise, the values
# are sat or unsat based on the majority of the model checkers.
hwmcc20_results: pd.DataFrame = pd.read_csv('../hwmcc20-results.csv')
hwmcc20_results['index'] = hwmcc20_results['index'].apply(lambda idx: idx + '.smt2')
hwmcc20_results.head()
# Out:
#                                 index   result  sat_count  uns_count  \
# 0    array-VexRiscv-regch0-15-p0.smt2    unsat          0          5
# 1    array-VexRiscv-regch0-15-p1.smt2    unsat          0          5
# 2    array-VexRiscv-regch0-20-p0.smt2    unsat          0          4
# 3  array-arbitrated_fifos_n2d8w8.smt2  unknown          0          0
# 4               array-array_swap.smt2  unknown          0          0
#
#    unk_count  low_bound  high_bound  avg_bound  low_real  high_real  avg_real  \
# 0          0         -1          -1       -1.0      9.40    2857.39   586.858
# 1          0         -1          -1       -1.0      9.59    3105.02   641.160
# 2          0         -1          -1       -1.0    228.44    3600.10  1017.224
# 3          2         -1          -1       -1.0      0.74    3600.10  2874.864
# 4          2         -1          -1       -1.0      0.42    3600.10  2875.386
#
#    low_time  high_timeavg_time  low_mem  high_mem  avg_mem   avg_time  \
# 0      9.30                NaN     82.0    2633.0   1112.0   1779.746
# 1      9.46                NaN     79.0    4350.0   1388.4   1355.362
# 2    228.36                NaN    209.0   10376.0   3061.4   3822.140
# 3      1.46                NaN     82.0    4803.0   1544.2  10024.040
# 4      0.09                NaN     31.0   24699.0   9013.2  13639.468
#
#    high_time
# 0    8570.64
# 1    6296.49
# 2    8203.90
# 3   28426.36
# 4   46507.75

# %%
hwmcc20_results[['result', 'index']].groupby(['result']).count()
# Out:
#          index
# result
# sat         84
# unknown     43
# unsat      512

# %% [markdown]
# ## Compare Gspacer and HWMCC20 modelcheckers

# %%
m: pd.DataFrame = pd.merge(df, hwmcc20_results, on='index')
m.head()
# Out:
#                                 index  SPACER_cex_depth  \
# 0    array-VexRiscv-regch0-15-p0.smt2               NaN
# 1    array-VexRiscv-regch0-15-p1.smt2               NaN
# 2    array-VexRiscv-regch0-20-p0.smt2               NaN
# 3  array-arbitrated_fifos_n2d8w8.smt2               NaN
# 4               array-array_swap.smt2               NaN
#
#    SPACER_cluster_out_of_gas  SPACER_conj  SPACER_conj_failed  \
# 0                        NaN          NaN                 NaN
# 1                        NaN          NaN                 NaN
# 2                        NaN          NaN                 NaN
# 3                       21.0          2.0                 2.0
# 4                        NaN          NaN                 NaN
#
#    SPACER_conj_success  SPACER_inductive_level  SPACER_max_depth  \
# 0                  NaN                     NaN               8.0
# 1                  NaN                     NaN               8.0
# 2                  NaN                     NaN               9.0
# 3                  NaN                     NaN              20.0
# 4                  NaN                     NaN               2.0
#
#    SPACER_max_query_lvl  SPACER_non_local_gen  ...  low_real  high_real  \
# 0                   8.0                   NaN  ...      9.40    2857.39
# 1                   8.0                   NaN  ...      9.59    3105.02
# 2                   9.0                   NaN  ...    228.44    3600.10
# 3                  19.0                   2.0  ...      0.74    3600.10
# 4                   1.0                   NaN  ...      0.42    3600.10
#
#    avg_real  low_time  high_timeavg_time  low_mem  high_mem  avg_mem  \
# 0   586.858      9.30                NaN     82.0    2633.0   1112.0
# 1   641.160      9.46                NaN     79.0    4350.0   1388.4
# 2  1017.224    228.36                NaN    209.0   10376.0   3061.4
# 3  2874.864      1.46                NaN     82.0    4803.0   1544.2
# 4  2875.386      0.09                NaN     31.0   24699.0   9013.2
#
#     avg_time  high_time
# 0   1779.746    8570.64
# 1   1355.362    6296.49
# 2   3822.140    8203.90
# 3  10024.040   28426.36
# 4  13639.468   46507.75
#
# [5 rows x 67 columns]

# %%
m[['status', 'index', 'result']].groupby(['status', 'result']).count()
# Out:
#                      index
# status      result
# (no status) sat          3
#             unsat        3
# sat         sat         12
#             unsat       10
# timeout     sat         69
#             unknown     39
#             unsat      193
# unknown     unknown      3
#             unsat       31
# unsat       unknown      1
#             unsat      275

# %%
# {sat|uns|unk}_count: The number of model checkers
#                      that gives {sat|unsat|unknown}
query_columns: List[str] = ['index', 'status', 'result', 'time', 'memory',
                            'sat_count', 'uns_count', 'unk_count']
m.query('status == "sat" & result == "unsat"')[query_columns].sort_values('time')
# Out:
#                                     index status result  time  memory  \
# 443                          bv-miim.smt2    sat  unsat  0.03    8.77
# 582                      bv-stack-p2.smt2    sat  unsat  0.04   10.47
# 585    bv-vcegar_arrays_itc99_b12_p2.smt2    sat  unsat  0.04    9.92
# 559                      bv-rast-p11.smt2    sat  unsat  0.06   10.53
# 424  bv-elevator.4.prop1-func-interl.smt2    sat  unsat  0.07   11.17
# 554                      bv-rast-p00.smt2    sat  unsat  0.07   11.12
# 560                      bv-rast-p14.smt2    sat  unsat  0.11   15.64
# 561                      bv-rast-p16.smt2    sat  unsat  0.12   15.64
# 562                      bv-rast-p17.smt2    sat  unsat  0.14   14.16
# 444     bv-msmie.3.prop1-func-interl.smt2    sat  unsat  0.35   32.25
#
#      sat_count  uns_count  unk_count
# 443          0          9          1
# 582          0         10          1
# 585          0          1          1
# 559          0         10          1
# 424          0          9          1
# 554          0          6          1
# 560          0          2          1
# 561          0          4          1
# 562          0          1          1
# 444          0          5          1

# %% [markdown]
# For `bv-vcegar_arrays_itc99_b12_p2.smt2` and `bv-rast-p17.smt2`, only nmtip says unsat.

# %%
m.query('status == "unsat" & result == "sat"')[query_columns].sort_values('time')
# Out:
# Empty DataFrame
# Columns: [index, status, result, time, memory, sat_count, uns_count, unk_count]
# Index: []

# %%
m.query('status == "sat" & result == "unknown"')[query_columns].sort_values('time')
# Out:
# Empty DataFrame
# Columns: [index, status, result, time, memory, sat_count, uns_count, unk_count]
# Index: []

# %%
m.query('status == "unsat" & result == "unknown"')[query_columns].sort_values('time')
# Out:
#                              index status   result  time  memory  sat_count  \
# 168  array-simple-stack-pred1.smt2  unsat  unknown   0.1   10.29          0
#
#      uns_count  unk_count
# 168          0          1

# %%
plt.xlim(0, timeout)
plt.ylim(0, timeout)
g = sns.scatterplot(x='time', y='avg_real', hue='status', style='result', data=m)
sns.despine()
x = np.linspace(0, timeout, 2)
g.plot(x, x)

# %% [markdown]
# ## BV

# %%
df_bv: pd.DataFrame = df[df['index'].str.startswith('bv-')]
df_bv.head()
# Out:
#                                      index  SPACER_cex_depth  \
# 315          bv-VexRiscv-regch0-15-p0.smt2               NaN
# 316          bv-VexRiscv-regch0-20-p0.smt2               NaN
# 317          bv-VexRiscv-regch0-30-p1.smt2               NaN
# 318  bv-anderson.3.prop1-back-serstep.smt2               4.0
# 319  bv-arbitrated_top_n2_w128_d32_e0.smt2               NaN
#
#      SPACER_cluster_out_of_gas  SPACER_conj  SPACER_conj_failed  \
# 315                        NaN          NaN                 NaN
# 316                        NaN          NaN                 NaN
# 317                        NaN          NaN                 NaN
# 318                        NaN          NaN                 NaN
# 319                        NaN          NaN                 NaN
#
#      SPACER_conj_success  SPACER_inductive_level  SPACER_max_depth  \
# 315                  NaN                     NaN              14.0
# 316                  NaN                     NaN              12.0
# 317                  NaN                     NaN              11.0
# 318                  NaN                     NaN               4.0
# 319                  NaN                     NaN              12.0
#
#      SPACER_max_query_lvl  SPACER_non_local_gen  ...  \
# 315                  13.0                   NaN  ...
# 316                  11.0                   NaN  ...
# 317                  10.0                   NaN  ...
# 318                   4.0                   NaN  ...
# 319                  11.0                   2.0  ...
#
#      time_spacer_init_rules_pt_init  time_spacer_mbp  time_spacer_solve  \
# 315                            0.09           157.44             777.14
# 316                            0.09           176.07             892.53
# 317                            0.09            36.35             210.47
# 318                            0.00             0.01              16.32
# 319                            0.10            32.38             842.14
#
#      time_spacer_solve_propagate  time_spacer_solve_reach  \
# 315                        68.29                   708.80
# 316                        60.11                   832.39
# 317                        22.79                   187.65
# 318                         0.29                    16.01
# 319                       126.52                   715.58
#
#      time_spacer_solve_reach_children  time_spacer_solve_reach_cluster  \
# 315                            162.31                            17.17
# 316                            179.91                             1.41
# 317                             37.86                             0.90
# 318                              0.02                             0.00
# 319                             34.10                             8.18
#
#      time_spacer_solve_reach_gen_bool_ind  time_spacer_solve_reach_gen_global  \
# 315                                426.78                                0.01
# 316                                529.74                                 NaN
# 317                                115.75                                 NaN
# 318                                 11.58                                 NaN
# 319                                573.83                                0.39
#
#      time_spacer_solve_reach_is_reach
# 315                               NaN
# 316                               NaN
# 317                               NaN
# 318                              1.41
# 319                              2.13
#
# [5 rows x 50 columns]

# %%
# quick overview of solved/unsolved instances
df_bv[['status', 'index']].groupby(['status']).count()
# Out:
#              index
# status
# (no status)      1
# sat             22
# timeout        211
# unknown          2
# unsat           88

# %%
df_bv.query('status == "(no status)"')[['index', 'status']]
# Out:
#                                    index       status
# 634  bv-zipversa_composecrc_prf-p10.smt2  (no status)

# %%
unknown_df_bv: pd.DataFrame = unknown_df[unknown_df['index'].str.startswith('bv-')]
unknown_df_bv.head()
# Out:
#                           index   status  \
# 460  bv-picorv32-pcregs-p0.smt2  unknown
# 461  bv-picorv32-pcregs-p2.smt2  unknown
#
#                                                                                error
# 460  (error "query failed: rule validation failed when checking: (and (not false))")
# 461  (error "query failed: rule validation failed when checking: (and (not false))")

# %%
unknown_df_bv.groupby('error')[['index']].agg(['first', 'count'])
# Out:
#                                                                                                       index  \
#                                                                                                       first
# error
# (error "query failed: rule validation failed when checking: (and (not false))")  bv-picorv32-pcregs-p0.smt2
#
#
#                                                                                 count
# error
# (error "query failed: rule validation failed when checking: (and (not false))")     2

# %%
df_ratio_bv: pd.DataFrame = df_ratio[df_ratio['index'].str.startswith('bv-')]
df_ratio_bv[(df_ratio_bv['ratio'] < 0.5) & (df_ratio_bv['time_spacer_solve'] > 10)]\
    [['index', 'time_pool_solver_smt_total', 'time_spacer_solve', 'ratio']]\
    .sort_values('ratio', ascending=True)
# Out:
#                                      index  time_pool_solver_smt_total  \
# 407  bv-dspfilters_fastfir_second-p04.smt2                        1.57
# 394                          bv-cal97.smt2                      139.10
# 420  bv-dspfilters_fastfir_second-p26.smt2                      153.81
# 419  bv-dspfilters_fastfir_second-p25.smt2                       80.69
# 411  bv-dspfilters_fastfir_second-p09.smt2                       67.31
# 583                bv-vcegar_QF_BV_ar.smt2                        3.87
# 409  bv-dspfilters_fastfir_second-p06.smt2                       78.82
# 371                         bv-cal176.smt2                      285.70
# 363                         bv-cal140.smt2                        7.19
# 364                         bv-cal142.smt2                        7.16
# 474        bv-picorv32_mutBY_nomem-p6.smt2                       82.64
# 467        bv-picorv32_mutAY_nomem-p6.smt2                       86.42
# 358                         bv-cal119.smt2                        5.78
# 473        bv-picorv32_mutBY_nomem-p4.smt2                       83.99
# 410  bv-dspfilters_fastfir_second-p07.smt2                      111.14
# 360                         bv-cal123.smt2                        6.11
# 475        bv-picorv32_mutBY_nomem-p7.smt2                      106.12
# 354                         bv-cal107.smt2                       52.48
# 395                          bv-cal99.smt2                       11.58
# 365                         bv-cal143.smt2                        9.41
# 439    bv-marlann_compute_cp_fail1-p2.smt2                       49.07
#
#      time_spacer_solve     ratio
# 407             810.30  0.001938
# 394             862.77  0.161225
# 420             888.76  0.173061
# 419             337.71  0.238933
# 411             227.26  0.296181
# 583              12.76  0.303292
# 409             229.76  0.343054
# 371             818.56  0.349028
# 363              16.94  0.424439
# 364              16.78  0.426698
# 474             191.93  0.430574
# 467             195.81  0.441346
# 358              12.94  0.446677
# 473             187.33  0.448353
# 410             239.90  0.463276
# 360              13.02  0.469278
# 475             225.75  0.470078
# 354             110.17  0.476355
# 395              24.05  0.481497
# 365              19.46  0.483556
# 439              99.82  0.491585

# %%
df_max_expand_time_bv: pd.DataFrame = df_max_expand_time[df_max_expand_time['index'].str.startswith('bv-')]
df_max_expand_time_bv[df_max_expand_time_bv['max_expand_time'] > 5]\
    [['index', 'max_expand_time', 'max_expand_time_line_no']]\
    .sort_values('max_expand_time', ascending=False)
# Out:
#                                          index  max_expand_time  \
# 407      bv-dspfilters_fastfir_second-p04.smt2           808.54
# 394                              bv-cal97.smt2           649.24
# 371                             bv-cal176.smt2           467.60
# 418      bv-dspfilters_fastfir_second-p22.smt2           305.79
# 411      bv-dspfilters_fastfir_second-p09.smt2           271.81
# 333      bv-arbitrated_top_n4_w128_d16_e0.smt2           249.76
# 412      bv-dspfilters_fastfir_second-p10.smt2           216.83
# 355                             bv-cal112.smt2           199.72
# 420      bv-dspfilters_fastfir_second-p26.smt2           127.60
# 351                     bv-buggy_ridecore.smt2           123.72
# 354                             bv-cal107.smt2           109.61
# 352                             bv-cal102.smt2           106.34
# 569     bv-shift_register_top_w128_d64_e0.smt2           103.44
# 566                           bv-ridecore.smt2            94.50
# 353                             bv-cal106.smt2            82.91
# 410      bv-dspfilters_fastfir_second-p07.smt2            81.60
# 381                             bv-cal227.smt2            65.19
# 378                             bv-cal210.smt2            63.87
# 448                               bv-mul7.smt2            49.90
# 608                bv-zipcpu-busdelay-p15.smt2            49.42
# 568     bv-shift_register_top_w128_d16_e0.smt2            42.85
# 329      bv-arbitrated_top_n3_w64_d128_e0.smt2            36.50
# 480          bv-ponylink-slaveTXlen-unsat.smt2            35.47
# 341      bv-arbitrated_top_n5_w128_d64_e0.smt2            32.71
# 575     bv-shift_register_top_w32_d128_e0.smt2            31.62
# 396  bv-circular_pointer_top_w128_d128_e0.smt2            29.37
# 404   bv-circular_pointer_top_w64_d128_e0.smt2            24.70
# 361                             bv-cal125.smt2            24.57
# 398    bv-circular_pointer_top_w128_d8_e0.smt2            22.85
# 397   bv-circular_pointer_top_w128_d64_e0.smt2            21.98
# 360                             bv-cal123.smt2            20.94
# 447                               bv-mul3.smt2            20.24
# 319      bv-arbitrated_top_n2_w128_d32_e0.smt2            20.05
# 320      bv-arbitrated_top_n2_w128_d64_e0.smt2            19.41
# 477            bv-picorv32_mutCX_nomem-p8.smt2            18.79
# 425          bv-frogs.5.prop1-func-interl.smt2            18.57
# 366                             bv-cal149.smt2            16.84
# 342       bv-arbitrated_top_n5_w128_d8_e0.smt2            15.89
# 571      bv-shift_register_top_w16_d16_e0.smt2            14.96
# 357                             bv-cal118.smt2            14.91
# 358                             bv-cal119.smt2            14.90
# 356                             bv-cal117.smt2            14.77
# 339       bv-arbitrated_top_n4_w64_d32_e0.smt2            13.57
# 330       bv-arbitrated_top_n3_w64_d64_e0.smt2            13.43
# 364                             bv-cal142.smt2            13.23
# 419      bv-dspfilters_fastfir_second-p25.smt2            12.64
# 438          bv-krebs.3.prop1-func-interl.smt2            11.89
# 612                bv-zipcpu-busdelay-p46.smt2            11.75
# 372                             bv-cal192.smt2            11.67
# 315              bv-VexRiscv-regch0-15-p0.smt2            11.15
# 453  bv-pgm_protocol.7.prop1-back-serstep.smt2            10.84
# 462            bv-picorv32_mutAX_nomem-p0.smt2            10.65
# 403    bv-circular_pointer_top_w32_d32_e0.smt2            10.62
# 344       bv-arbitrated_top_n5_w64_d16_e0.smt2            10.55
# 321       bv-arbitrated_top_n2_w64_d64_e0.smt2            10.54
# 593                bv-vgasim_imgfifo-p088.smt2            10.43
# 395                              bv-cal99.smt2            10.30
# 334      bv-arbitrated_top_n4_w128_d64_e0.smt2            10.13
# 626                  bv-zipcpu-zipmmu-p26.smt2             9.80
# 380                             bv-cal224.smt2             9.49
# 350          bv-brp2.6.prop3-back-serstep.smt2             9.39
# 362                             bv-cal129.smt2             8.87
# 393                              bv-cal90.smt2             8.73
# 349          bv-brp2.3.prop1-back-serstep.smt2             8.42
# 374                             bv-cal201.smt2             8.14
# 618                 bv-zipcpu-pfcache-p22.smt2             8.01
# 597                bv-vgasim_imgfifo-p105.smt2             8.01
# 464            bv-picorv32_mutAX_nomem-p5.smt2             7.83
# 570     bv-shift_register_top_w16_d128_e0.smt2             7.61
# 619                 bv-zipcpu-pfcache-p24.smt2             7.60
# 409      bv-dspfilters_fastfir_second-p06.smt2             7.40
# 359                             bv-cal122.smt2             7.27
# 365                             bv-cal143.smt2             7.24
# 317              bv-VexRiscv-regch0-30-p1.smt2             7.14
# 600                bv-vgasim_imgfifo-p111.smt2             7.13
# 363                             bv-cal140.smt2             7.07
# 573      bv-shift_register_top_w16_d64_e0.smt2             7.07
# 347        bv-blocks.4.prop1-back-serstep.smt2             7.06
# 415      bv-dspfilters_fastfir_second-p16.smt2             6.93
# 348           bv-brp2.2.prop1-func-interl.smt2             6.88
# 577       bv-shift_register_top_w32_d8_e0.smt2             6.81
# 442           bv-mcs.3.prop1-back-serstep.smt2             6.67
# 399   bv-circular_pointer_top_w16_d128_e0.smt2             6.53
# 476            bv-picorv32_mutCX_nomem-p0.smt2             6.53
# 463            bv-picorv32_mutAX_nomem-p2.smt2             6.42
# 402    bv-circular_pointer_top_w32_d16_e0.smt2             6.36
# 615                 bv-zipcpu-pfcache-p02.smt2             6.12
# 468            bv-picorv32_mutBX_nomem-p0.smt2             6.03
# 586                bv-vgasim_imgfifo-p036.smt2             6.01
# 591                bv-vgasim_imgfifo-p075.smt2             5.96
# 470            bv-picorv32_mutBX_nomem-p8.smt2             5.90
# 316              bv-VexRiscv-regch0-20-p0.smt2             5.88
# 375                             bv-cal206.smt2             5.64
# 327       bv-arbitrated_top_n3_w16_d32_e0.smt2             5.62
# 592                bv-vgasim_imgfifo-p082.smt2             5.56
# 614                 bv-zipcpu-pfcache-p01.smt2             5.52
# 459                 bv-picorv32-check-p22.smt2             5.44
# 590                bv-vgasim_imgfifo-p070.smt2             5.41
# 452   bv-pgm_protocol.3.prop5-func-interl.smt2             5.38
# 337       bv-arbitrated_top_n4_w16_d64_e0.smt2             5.26
# 373                               bv-cal2.smt2             5.23
# 326      bv-arbitrated_top_n3_w16_d128_e0.smt2             5.01
#
#      max_expand_time_line_no
# 407                     3099
# 394                     1323
# 371                     4910
# 418                    23328
# 411                    10104
# 333                    13419
# 412                    24417
# 355                      620
# 420                      966
# 351                      226
# 354                      404
# 352                      565
# 569                     1450
# 566                      211
# 353                      399
# 410                     6166
# 381                     1083
# 378                      439
# 448                      193
# 608                     2697
# 568                      730
# 329                      504
# 480                    13521
# 341                     2861
# 575                      985
# 396                      873
# 404                     2354
# 361                     9230
# 398                     2516
# 397                     1085
# 360                     7960
# 447                      237
# 319                     4708
# 320                     5166
# 477                     7286
# 425                      879
# 366                     6929
# 342                    12207
# 571                     3662
# 357                    13454
# 358                     9537
# 356                    12919
# 339                    18092
# 330                     5339
# 364                      229
# 419                     8084
# 438                     3211
# 612                     4783
# 372                      233
# 315                    14040
# 453                     1908
# 462                     1508
# 403                     3550
# 344                    14626
# 321                     4784
# 593                     2049
# 395                     8457
# 334                     5873
# 626                    11509
# 380                     1362
# 350                     4094
# 362                     4378
# 393                     8643
# 349                     2954
# 374                      214
# 618                     8515
# 597                     2880
# 464                     7327
# 570                     3244
# 619                     8828
# 409                    15992
# 359                      756
# 365                      267
# 317                    12489
# 600                     2418
# 363                      171
# 573                     4011
# 347                     2050
# 415                      317
# 348                     5483
# 577                     2667
# 442                     2433
# 399                     2199
# 476                     6853
# 463                     4838
# 402                     4389
# 615                     8139
# 468                     3353
# 586                     3238
# 591                     2735
# 470                     1340
# 316                     8760
# 375                      212
# 327                    19636
# 592                     2874
# 614                     7690
# 459                     5721
# 590                     2792
# 452                     4468
# 337                    17554
# 373                      610
# 326                      300

# %%
hwmcc20_results_bv: pd.DataFrame = hwmcc20_results[hwmcc20_results['index'].str.startswith('bv-')]
hwmcc20_results_bv.head()
# Out:
#                                      index result  sat_count  uns_count  \
# 315          bv-VexRiscv-regch0-15-p0.smt2  unsat          0          8
# 316          bv-VexRiscv-regch0-20-p0.smt2  unsat          0          8
# 317          bv-VexRiscv-regch0-30-p1.smt2  unsat          0          6
# 318  bv-anderson.3.prop1-back-serstep.smt2    sat         11          0
# 319  bv-arbitrated_top_n2_w128_d32_e0.smt2    sat          5          0
#
#      unk_count  low_bound  high_bound  avg_bound  low_real  high_real  \
# 315          1         -1          -1  -1.000000      6.28    3600.11
# 316          1         -1          -1  -1.000000     52.68    3600.10
# 317          1         -1          -1  -1.000000    254.53    3600.11
# 318          0         -1           4   1.272727      0.03       3.13
# 319          0         -1          -1  -1.000000    591.76    3600.11
#
#         avg_real  low_time  high_timeavg_time  low_mem  high_mem  \
# 315   680.350909      6.19                NaN     91.0   16828.0
# 316   891.460909     52.59                NaN    161.0   31820.0
# 317  2101.825455    254.49                NaN    722.0  110681.0
# 318     0.594545      0.00                NaN      0.0    1753.0
# 319  2364.781818   1647.68                NaN    225.0   14825.0
#
#           avg_mem      avg_time  high_time
# 315   4166.545455   4722.890000   35991.59
# 316  10455.272727   6538.323636   35992.53
# 317  28088.818182  14905.270909   35903.45
# 318    309.363636      0.810909       4.54
# 319   5186.272727  15454.903636   44492.40

# %%
m_bv: pd.DataFrame = pd.merge(df_bv, hwmcc20_results_bv, on='index')
m_bv.head()
# Out:
#                                    index  SPACER_cex_depth  \
# 0          bv-VexRiscv-regch0-15-p0.smt2               NaN
# 1          bv-VexRiscv-regch0-20-p0.smt2               NaN
# 2          bv-VexRiscv-regch0-30-p1.smt2               NaN
# 3  bv-anderson.3.prop1-back-serstep.smt2               4.0
# 4  bv-arbitrated_top_n2_w128_d32_e0.smt2               NaN
#
#    SPACER_cluster_out_of_gas  SPACER_conj  SPACER_conj_failed  \
# 0                        NaN          NaN                 NaN
# 1                        NaN          NaN                 NaN
# 2                        NaN          NaN                 NaN
# 3                        NaN          NaN                 NaN
# 4                        NaN          NaN                 NaN
#
#    SPACER_conj_success  SPACER_inductive_level  SPACER_max_depth  \
# 0                  NaN                     NaN              14.0
# 1                  NaN                     NaN              12.0
# 2                  NaN                     NaN              11.0
# 3                  NaN                     NaN               4.0
# 4                  NaN                     NaN              12.0
#
#    SPACER_max_query_lvl  SPACER_non_local_gen  ...  low_real  high_real  \
# 0                  13.0                   NaN  ...      6.28    3600.11
# 1                  11.0                   NaN  ...     52.68    3600.10
# 2                  10.0                   NaN  ...    254.53    3600.11
# 3                   4.0                   NaN  ...      0.03       3.13
# 4                  11.0                   2.0  ...    591.76    3600.11
#
#       avg_real  low_time  high_timeavg_time  low_mem  high_mem       avg_mem  \
# 0   680.350909      6.19                NaN     91.0   16828.0   4166.545455
# 1   891.460909     52.59                NaN    161.0   31820.0  10455.272727
# 2  2101.825455    254.49                NaN    722.0  110681.0  28088.818182
# 3     0.594545      0.00                NaN      0.0    1753.0    309.363636
# 4  2364.781818   1647.68                NaN    225.0   14825.0   5186.272727
#
#        avg_time  high_time
# 0   4722.890000   35991.59
# 1   6538.323636   35992.53
# 2  14905.270909   35903.45
# 3      0.810909       4.54
# 4  15454.903636   44492.40
#
# [5 rows x 67 columns]

# %%
m_bv[['status', 'index', 'result']].groupby(['status', 'result']).count()
# Out:
#                      index
# status      result
# (no status) unsat        1
# sat         sat         12
#             unsat       10
# timeout     sat         53
#             unknown     19
#             unsat      139
# unknown     unknown      2
# unsat       unsat       88

# %%
plt.xlim(0, timeout)
plt.ylim(0, timeout)
g = sns.scatterplot(x='time', y='avg_real', hue='status', style='result', data=m_bv)
sns.despine()
x = np.linspace(0, timeout, 2)
g.plot(x, x)

# %% [markdown]
# ## Array

# %%
df_array: pd.DataFrame = df[df['index'].str.startswith('array-')]
df_array.head()
# Out:
#                                 index  SPACER_cex_depth  \
# 0    array-VexRiscv-regch0-15-p0.smt2               NaN
# 1    array-VexRiscv-regch0-15-p1.smt2               NaN
# 2    array-VexRiscv-regch0-20-p0.smt2               NaN
# 3  array-arbitrated_fifos_n2d8w8.smt2               NaN
# 4               array-array_swap.smt2               NaN
#
#    SPACER_cluster_out_of_gas  SPACER_conj  SPACER_conj_failed  \
# 0                        NaN          NaN                 NaN
# 1                        NaN          NaN                 NaN
# 2                        NaN          NaN                 NaN
# 3                       21.0          2.0                 2.0
# 4                        NaN          NaN                 NaN
#
#    SPACER_conj_success  SPACER_inductive_level  SPACER_max_depth  \
# 0                  NaN                     NaN               8.0
# 1                  NaN                     NaN               8.0
# 2                  NaN                     NaN               9.0
# 3                  NaN                     NaN              20.0
# 4                  NaN                     NaN               2.0
#
#    SPACER_max_query_lvl  SPACER_non_local_gen  ...  \
# 0                   8.0                   NaN  ...
# 1                   8.0                   NaN  ...
# 2                   9.0                   NaN  ...
# 3                  19.0                   2.0  ...
# 4                   1.0                   NaN  ...
#
#    time_spacer_init_rules_pt_init  time_spacer_mbp  time_spacer_solve  \
# 0                            0.06            13.96             124.64
# 1                            0.06             3.25              34.20
# 2                            0.06            15.49             153.23
# 3                            0.00            33.13             638.42
# 4                             NaN              NaN               0.01
#
#    time_spacer_solve_propagate  time_spacer_solve_reach  \
# 0                         0.86                   123.75
# 1                         3.00                    31.18
# 2                         8.65                   144.55
# 3                       195.09                   443.25
# 4                         0.00                     0.00
#
#    time_spacer_solve_reach_children  time_spacer_solve_reach_cluster  \
# 0                             15.31                             0.69
# 1                              3.83                             0.04
# 2                             16.77                             0.31
# 3                             29.43                             7.32
# 4                               NaN                              NaN
#
#    time_spacer_solve_reach_gen_bool_ind  time_spacer_solve_reach_gen_global  \
# 0                                 86.06                                 NaN
# 1                                 20.25                                 NaN
# 2                                103.92                                 NaN
# 3                                290.13                                4.88
# 4                                   NaN                                 NaN
#
#    time_spacer_solve_reach_is_reach
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                              1.59
# 4                               NaN
#
# [5 rows x 50 columns]

# %%
# quick overview of solved/unsolved instances
df_array[['status', 'index']].groupby('status').count()
# Out:
#              index
# status
# (no status)      5
# timeout         90
# unknown         32
# unsat          188

# %%
df_array.query('status == "(no status)"')[['index', 'status']]
# Out:
#                                             index       status
# 92   array-dblclockfft_butterfly_ck3_r0-p051.smt2  (no status)
# 105  array-dblclockfft_butterfly_ck3_r1-p049.smt2  (no status)
# 135           array-marlann_compute_fail1-p0.smt2  (no status)
# 138           array-marlann_compute_fail2-p1.smt2  (no status)
# 139           array-marlann_compute_fail2-p2.smt2  (no status)

# %%
unknown_df_array: pd.DataFrame = unknown_df[unknown_df['index'].str.startswith('array-')]
unknown_df_array.head()
# Out:
#                                         index   status  \
# 0            array-VexRiscv-regch0-15-p0.smt2  unknown
# 1            array-VexRiscv-regch0-15-p1.smt2  unknown
# 2            array-VexRiscv-regch0-20-p0.smt2  unknown
# 4                       array-array_swap.smt2  unknown
# 10  array-dblclockfft_butterfly_ck1-p063.smt2  unknown
#
#                                                                                                                                                      error
# 0        (error "query failed: Argument #b11111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")
# 1        (error "query failed: Argument #b11111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")
# 2        (error "query failed: Argument #b00011 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")
# 4   (error "query failed: Argument #b1111111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")
# 10                                                                         (error "query failed: rule validation failed when checking: (exists ((x!1 Bool)

# %%
unknown_df.groupby('error')[['index']].agg(['first', 'count'])
# Out:
#                                                                                                                                                                                                index  \
#                                                                                                                                                                                                first
# error
# (error "query failed: Argument #b00011 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")                   array-VexRiscv-regch0-20-p0.smt2
# (error "query failed: Argument #b11 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 20) (_ BitVec 20)) (_ BitVec 20))")                          array-zipcpu-zipmmu-p26.smt2
# (error "query failed: Argument #b11111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")                   array-VexRiscv-regch0-15-p0.smt2
# (error "query failed: Argument #b1111111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")                         array-array_swap.smt2
# (error "query failed: operator is applied to arguments of the wrong sort")                                                                              array-dblclockfft_butterfly_ck3_r2-p042.smt2
# (error "query failed: rule validation failed when checking: (and (not false))")                                                                                           bv-picorv32-pcregs-p0.smt2
# (error "query failed: rule validation failed when checking: (exists ((x!1 Bool)                                                                            array-dblclockfft_butterfly_ck1-p063.smt2
#
#
#                                                                                                                                                        count
# error
# (error "query failed: Argument #b00011 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")          1
# (error "query failed: Argument #b11 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 20) (_ BitVec 20)) (_ BitVec 20))")             2
# (error "query failed: Argument #b11111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")          3
# (error "query failed: Argument #b1111111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")     2
# (error "query failed: operator is applied to arguments of the wrong sort")                                                                                 1
# (error "query failed: rule validation failed when checking: (and (not false))")                                                                            2
# (error "query failed: rule validation failed when checking: (exists ((x!1 Bool)                                                                           23

# %%
df_ratio_array: pd.DataFrame = df_ratio[df_ratio['index'].str.startswith('array-')]
df_ratio_array[(df_ratio_array['ratio'] < 0.5) & (df_ratio_array['time_spacer_solve'] > 10)]\
    [['index', 'time_pool_solver_smt_total', 'time_spacer_solve', 'ratio']]\
    .sort_values('ratio', ascending=True)
# Out:
#                                          index  time_pool_solver_smt_total  \
# 11   array-dblclockfft_butterfly_ck1-p068.smt2                       50.92
# 17   array-dblclockfft_butterfly_ck1-p117.smt2                       79.92
# 43   array-dblclockfft_butterfly_ck1-p343.smt2                       12.36
# 34   array-dblclockfft_butterfly_ck1-p269.smt2                       13.38
# 45   array-dblclockfft_butterfly_ck1-p348.smt2                        3.76
# 21   array-dblclockfft_butterfly_ck1-p167.smt2                       15.86
# 51   array-dblclockfft_butterfly_ck1-p375.smt2                        4.04
# 14   array-dblclockfft_butterfly_ck1-p078.smt2                        6.99
# 58   array-dblclockfft_butterfly_ck1-p436.smt2                       11.21
# 57   array-dblclockfft_butterfly_ck1-p434.smt2                        4.68
# 55   array-dblclockfft_butterfly_ck1-p428.smt2                        5.46
# 52   array-dblclockfft_butterfly_ck1-p386.smt2                       44.20
# 295        array-zipcpu_zipcpu_piped-p389.smt2                      109.67
# 10   array-dblclockfft_butterfly_ck1-p063.smt2                       43.99
# 44   array-dblclockfft_butterfly_ck1-p346.smt2                       34.44
# 42   array-dblclockfft_butterfly_ck1-p341.smt2                       23.50
# 179       array-zipcpu_zipcpu_dcache-p028.smt2                      278.97
# 26   array-dblclockfft_butterfly_ck1-p212.smt2                        4.91
# 218       array-zipcpu_zipcpu_dcache-p407.smt2                       39.56
# 183       array-zipcpu_zipcpu_dcache-p068.smt2                      304.87
# 6    array-dblclockfft_butterfly_ck1-p015.smt2                        9.63
# 48   array-dblclockfft_butterfly_ck1-p354.smt2                        5.87
# 36   array-dblclockfft_butterfly_ck1-p285.smt2                       14.10
# 50   array-dblclockfft_butterfly_ck1-p372.smt2                       49.59
# 214       array-zipcpu_zipcpu_dcache-p360.smt2                      174.89
# 40   array-dblclockfft_butterfly_ck1-p310.smt2                        5.41
# 206       array-zipcpu_zipcpu_dcache-p238.smt2                       30.47
# 196       array-zipcpu_zipcpu_dcache-p159.smt2                       16.80
# 238       array-zipcpu_zipcpu_dcache-p582.smt2                      137.10
# 47   array-dblclockfft_butterfly_ck1-p352.smt2                       27.88
# 302        array-zipcpu_zipcpu_piped-p466.smt2                      335.08
# 198       array-zipcpu_zipcpu_dcache-p179.smt2                       93.06
# 187       array-zipcpu_zipcpu_dcache-p082.smt2                      108.74
# 205       array-zipcpu_zipcpu_dcache-p237.smt2                       71.92
# 25   array-dblclockfft_butterfly_ck1-p200.smt2                       11.70
# 23   array-dblclockfft_butterfly_ck1-p191.smt2                      177.65
# 41   array-dblclockfft_butterfly_ck1-p333.smt2                       32.97
# 195       array-zipcpu_zipcpu_dcache-p158.smt2                      147.98
# 193       array-zipcpu_zipcpu_dcache-p138.smt2                      356.35
# 192       array-zipcpu_zipcpu_dcache-p126.smt2                      218.19
# 262        array-zipcpu_zipcpu_piped-p162.smt2                      399.98
# 232       array-zipcpu_zipcpu_dcache-p550.smt2                      328.31
# 16   array-dblclockfft_butterfly_ck1-p106.smt2                        5.07
# 194       array-zipcpu_zipcpu_dcache-p141.smt2                      355.87
#
#      time_spacer_solve     ratio
# 11              740.80  0.068737
# 17              465.06  0.171849
# 43               60.73  0.203524
# 34               56.58  0.236479
# 45               15.28  0.246073
# 21               64.21  0.247002
# 51               16.02  0.252185
# 14               26.65  0.262289
# 58               39.33  0.285024
# 57               16.01  0.292317
# 55               18.16  0.300661
# 52              145.77  0.303217
# 295             359.38  0.305164
# 10              141.17  0.311610
# 44              110.47  0.311759
# 42               73.63  0.319163
# 179             853.98  0.326670
# 26               15.02  0.326897
# 218             118.07  0.335055
# 183             898.09  0.339465
# 6                26.99  0.356799
# 48               16.05  0.365732
# 36               37.39  0.377106
# 50              130.38  0.380350
# 214             459.69  0.380452
# 40               14.06  0.384780
# 206              79.11  0.385160
# 196              43.39  0.387186
# 238             344.47  0.398003
# 47               69.65  0.400287
# 302             833.56  0.401987
# 198             229.52  0.405455
# 187             264.58  0.410991
# 205             174.67  0.411748
# 25               27.65  0.423146
# 23              408.10  0.435310
# 41               74.66  0.441602
# 195             323.70  0.457152
# 193             766.15  0.465118
# 192             467.16  0.467056
# 262             856.07  0.467228
# 232             695.25  0.472219
# 16               10.34  0.490329
# 194             712.26  0.499635

# %%
df_max_expand_time_array: pd.DataFrame = df_max_expand_time[df_max_expand_time['index'].str.startswith('array-')]
df_max_expand_time_array[df_max_expand_time_array['max_expand_time'] > 5]\
    [['index', 'max_expand_time', 'max_expand_time_line_no']]\
    .sort_values('max_expand_time', ascending=False)
# Out:
#                                             index  max_expand_time  \
# 151              array-picorv32_mutAY_mem-p8.smt2           414.41
# 11      array-dblclockfft_butterfly_ck1-p068.smt2           280.71
# 17      array-dblclockfft_butterfly_ck1-p117.smt2           237.35
# 118  array-dblclockfft_butterfly_ck3_r2-p029.smt2           145.65
# 179          array-zipcpu_zipcpu_dcache-p028.smt2            78.58
# 193          array-zipcpu_zipcpu_dcache-p138.smt2            73.60
# 23      array-dblclockfft_butterfly_ck1-p191.smt2            60.14
# 114  array-dblclockfft_butterfly_ck3_r1-p159.smt2            57.38
# 232          array-zipcpu_zipcpu_dcache-p550.smt2            53.35
# 80   array-dblclockfft_butterfly_ck2_r0-p173.smt2            52.99
# 214          array-zipcpu_zipcpu_dcache-p360.smt2            46.95
# 149              array-picorv32_mutAY_mem-p5.smt2            42.07
# 199          array-zipcpu_zipcpu_dcache-p192.smt2            41.75
# 192          array-zipcpu_zipcpu_dcache-p126.smt2            40.90
# 262           array-zipcpu_zipcpu_piped-p162.smt2            40.79
# 159              array-picorv32_mutCX_mem-p0.smt2            40.48
# 258           array-zipcpu_zipcpu_piped-p146.smt2            38.91
# 164              array-picorv32_mutCY_mem-p8.smt2            32.88
# 130  array-dblclockfft_butterfly_ck3_r2-p154.smt2            25.72
# 52      array-dblclockfft_butterfly_ck1-p386.smt2            25.68
# 166             array-ridecore_array_unknown.smt2            23.69
# 109  array-dblclockfft_butterfly_ck3_r1-p119.smt2            23.63
# 205          array-zipcpu_zipcpu_dcache-p237.smt2            20.84
# 19      array-dblclockfft_butterfly_ck1-p147.smt2            20.83
# 167              array-ridecore_array_unsafe.smt2            19.80
# 152              array-picorv32_mutBX_mem-p1.smt2            19.27
# 226          array-zipcpu_zipcpu_dcache-p506.smt2            17.54
# 218          array-zipcpu_zipcpu_dcache-p407.smt2            16.59
# 228          array-zipcpu_zipcpu_dcache-p519.smt2            16.42
# 147              array-picorv32_mutAX_mem-p0.smt2            16.10
# 238          array-zipcpu_zipcpu_dcache-p582.smt2            14.71
# 88   array-dblclockfft_butterfly_ck3_r0-p021.smt2            13.86
# 67   array-dblclockfft_butterfly_ck2_r0-p096.smt2            12.40
# 295           array-zipcpu_zipcpu_piped-p389.smt2            12.26
# 263           array-zipcpu_zipcpu_piped-p163.smt2            12.24
# 156              array-picorv32_mutBX_mem-p7.smt2            12.23
# 154              array-picorv32_mutBX_mem-p5.smt2            12.23
# 305           array-zipcpu_zipcpu_piped-p476.smt2            11.20
# 165          array-ponylink-slaveTXlen-unsat.smt2            11.00
# 302           array-zipcpu_zipcpu_piped-p466.smt2            10.97
# 104  array-dblclockfft_butterfly_ck3_r1-p047.smt2            10.96
# 203          array-zipcpu_zipcpu_dcache-p229.smt2            10.53
# 297           array-zipcpu_zipcpu_piped-p399.smt2            10.29
# 99   array-dblclockfft_butterfly_ck3_r0-p111.smt2             8.88
# 133  array-dblclockfft_butterfly_ck3_r2-p173.smt2             8.84
# 30      array-dblclockfft_butterfly_ck1-p255.smt2             8.45
# 236          array-zipcpu_zipcpu_dcache-p578.smt2             8.13
# 73   array-dblclockfft_butterfly_ck2_r0-p129.smt2             8.13
# 70   array-dblclockfft_butterfly_ck2_r0-p101.smt2             8.01
# 113  array-dblclockfft_butterfly_ck3_r1-p157.smt2             7.92
# 108  array-dblclockfft_butterfly_ck3_r1-p086.smt2             7.81
# 81   array-dblclockfft_butterfly_ck2_r0-p185.smt2             7.69
# 180          array-zipcpu_zipcpu_dcache-p034.smt2             7.57
# 66   array-dblclockfft_butterfly_ck2_r0-p095.smt2             7.42
# 98   array-dblclockfft_butterfly_ck3_r0-p090.smt2             7.38
# 230          array-zipcpu_zipcpu_dcache-p527.smt2             6.91
# 285           array-zipcpu_zipcpu_piped-p327.smt2             6.81
# 96   array-dblclockfft_butterfly_ck3_r0-p066.smt2             6.80
# 163              array-picorv32_mutCY_mem-p3.smt2             6.75
# 158              array-picorv32_mutBY_mem-p8.smt2             6.74
# 208          array-zipcpu_zipcpu_dcache-p286.smt2             6.63
# 157              array-picorv32_mutBY_mem-p4.smt2             6.54
# 153              array-picorv32_mutBX_mem-p2.smt2             6.52
# 240          array-zipcpu_zipcpu_dcache-p595.smt2             6.52
# 28      array-dblclockfft_butterfly_ck1-p222.smt2             6.51
# 291           array-zipcpu_zipcpu_piped-p351.smt2             6.49
# 77   array-dblclockfft_butterfly_ck2_r0-p159.smt2             6.33
# 160              array-picorv32_mutCX_mem-p3.smt2             6.21
# 155              array-picorv32_mutBX_mem-p6.smt2             6.12
# 249           array-zipcpu_zipcpu_piped-p081.smt2             6.11
# 91   array-dblclockfft_butterfly_ck3_r0-p048.smt2             6.06
# 222          array-zipcpu_zipcpu_dcache-p440.smt2             5.94
# 212          array-zipcpu_zipcpu_dcache-p340.smt2             5.93
# 94   array-dblclockfft_butterfly_ck3_r0-p053.smt2             5.88
# 224          array-zipcpu_zipcpu_dcache-p476.smt2             5.87
# 217          array-zipcpu_zipcpu_dcache-p388.smt2             5.79
# 161              array-picorv32_mutCX_mem-p7.smt2             5.57
# 106  array-dblclockfft_butterfly_ck3_r1-p054.smt2             5.32
# 162              array-picorv32_mutCY_mem-p1.smt2             5.30
# 269           array-zipcpu_zipcpu_piped-p211.smt2             5.26
# 90   array-dblclockfft_butterfly_ck3_r0-p042.smt2             5.23
# 72   array-dblclockfft_butterfly_ck2_r0-p106.smt2             5.15
# 303           array-zipcpu_zipcpu_piped-p472.smt2             5.13
#
#      max_expand_time_line_no
# 151                    11154
# 11                     12270
# 17                     10253
# 118                     2632
# 179                    14275
# 193                    10489
# 23                      9194
# 114                     6931
# 232                    15981
# 80                      6924
# 214                     8126
# 149                    30945
# 199                    13757
# 192                     6713
# 262                    15151
# 159                    10048
# 258                     5217
# 164                    12248
# 130                      744
# 52                      4133
# 166                     1204
# 109                     5630
# 205                     2267
# 19                     10234
# 167                      165
# 152                     9374
# 226                     8412
# 218                     7953
# 228                    13427
# 147                     9485
# 238                    15419
# 88                      6233
# 67                      2561
# 295                     3398
# 263                     4995
# 156                     8045
# 154                     2490
# 305                     3325
# 165                    14384
# 302                    28751
# 104                     8029
# 203                    13165
# 297                     1918
# 99                      4439
# 133                     1853
# 30                     13215
# 236                     3053
# 73                      6993
# 70                      7873
# 113                     1187
# 108                     6365
# 81                      4108
# 180                     3937
# 66                      8053
# 98                      6824
# 230                    17258
# 285                    14090
# 96                      5961
# 163                    22081
# 158                    25502
# 208                    17806
# 157                    25520
# 153                    13945
# 240                     8355
# 28                      5095
# 291                     4550
# 77                      3887
# 160                     1699
# 155                     2300
# 249                    14613
# 91                      3535
# 222                     5575
# 212                    14794
# 94                      4831
# 224                     6853
# 217                     7612
# 161                     3624
# 106                     2272
# 162                    27051
# 269                    12719
# 90                      6491
# 72                       851
# 303                     4580

# %%
hwmcc20_results_array: pd.DataFrame = hwmcc20_results[hwmcc20_results['index'].str.startswith('array-')]
hwmcc20_results_array.head()
# Out:
#                                 index   result  sat_count  uns_count  \
# 0    array-VexRiscv-regch0-15-p0.smt2    unsat          0          5
# 1    array-VexRiscv-regch0-15-p1.smt2    unsat          0          5
# 2    array-VexRiscv-regch0-20-p0.smt2    unsat          0          4
# 3  array-arbitrated_fifos_n2d8w8.smt2  unknown          0          0
# 4               array-array_swap.smt2  unknown          0          0
#
#    unk_count  low_bound  high_bound  avg_bound  low_real  high_real  avg_real  \
# 0          0         -1          -1       -1.0      9.40    2857.39   586.858
# 1          0         -1          -1       -1.0      9.59    3105.02   641.160
# 2          0         -1          -1       -1.0    228.44    3600.10  1017.224
# 3          2         -1          -1       -1.0      0.74    3600.10  2874.864
# 4          2         -1          -1       -1.0      0.42    3600.10  2875.386
#
#    low_time  high_timeavg_time  low_mem  high_mem  avg_mem   avg_time  \
# 0      9.30                NaN     82.0    2633.0   1112.0   1779.746
# 1      9.46                NaN     79.0    4350.0   1388.4   1355.362
# 2    228.36                NaN    209.0   10376.0   3061.4   3822.140
# 3      1.46                NaN     82.0    4803.0   1544.2  10024.040
# 4      0.09                NaN     31.0   24699.0   9013.2  13639.468
#
#    high_time
# 0    8570.64
# 1    6296.49
# 2    8203.90
# 3   28426.36
# 4   46507.75

# %%
m_array: pd.DataFrame = pd.merge(df_array, hwmcc20_results_array, on='index')
m_array.head()
# Out:
#                                 index  SPACER_cex_depth  \
# 0    array-VexRiscv-regch0-15-p0.smt2               NaN
# 1    array-VexRiscv-regch0-15-p1.smt2               NaN
# 2    array-VexRiscv-regch0-20-p0.smt2               NaN
# 3  array-arbitrated_fifos_n2d8w8.smt2               NaN
# 4               array-array_swap.smt2               NaN
#
#    SPACER_cluster_out_of_gas  SPACER_conj  SPACER_conj_failed  \
# 0                        NaN          NaN                 NaN
# 1                        NaN          NaN                 NaN
# 2                        NaN          NaN                 NaN
# 3                       21.0          2.0                 2.0
# 4                        NaN          NaN                 NaN
#
#    SPACER_conj_success  SPACER_inductive_level  SPACER_max_depth  \
# 0                  NaN                     NaN               8.0
# 1                  NaN                     NaN               8.0
# 2                  NaN                     NaN               9.0
# 3                  NaN                     NaN              20.0
# 4                  NaN                     NaN               2.0
#
#    SPACER_max_query_lvl  SPACER_non_local_gen  ...  low_real  high_real  \
# 0                   8.0                   NaN  ...      9.40    2857.39
# 1                   8.0                   NaN  ...      9.59    3105.02
# 2                   9.0                   NaN  ...    228.44    3600.10
# 3                  19.0                   2.0  ...      0.74    3600.10
# 4                   1.0                   NaN  ...      0.42    3600.10
#
#    avg_real  low_time  high_timeavg_time  low_mem  high_mem  avg_mem  \
# 0   586.858      9.30                NaN     82.0    2633.0   1112.0
# 1   641.160      9.46                NaN     79.0    4350.0   1388.4
# 2  1017.224    228.36                NaN    209.0   10376.0   3061.4
# 3  2874.864      1.46                NaN     82.0    4803.0   1544.2
# 4  2875.386      0.09                NaN     31.0   24699.0   9013.2
#
#     avg_time  high_time
# 0   1779.746    8570.64
# 1   1355.362    6296.49
# 2   3822.140    8203.90
# 3  10024.040   28426.36
# 4  13639.468   46507.75
#
# [5 rows x 67 columns]

# %%
m_array[['status', 'index', 'result']].groupby(['status', 'result']).count()
# Out:
#                      index
# status      result
# (no status) sat          3
#             unsat        2
# timeout     sat         16
#             unknown     20
#             unsat       54
# unknown     unknown      1
#             unsat       31
# unsat       unknown      1
#             unsat      187

# %%
plt.xlim(0, timeout)
plt.ylim(0, timeout)
g = sns.scatterplot(x='time', y='avg_real', hue='status', style='result', data=m_array)
sns.despine()
x = np.linspace(0, timeout, 2)
g.plot(x, x)
