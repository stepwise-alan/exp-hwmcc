# %% [markdown]
# # Analysis of Gspacer on HWMCC20 Rules
#
# - Start: Thursday, October 29, 2020, 5:01:38 PM
# - End: Friday, October 30, 2020, 0:24:12 AM
# - Duration: 7 hours, 22 minutes, and 34 seconds
# - Number of benchmarks: 639
# - Timeout: 900 seconds
# - Branch: `gpsacer`
# - Arguments: `-st -v:1 -T:900s fp.xform.slice=true fp.xform.inline_linear=true fp.xform.inline_eager=true fp.xform.tail_simplifier_pve=true fp.engine=spacer fp.print_statistics=true fp.spacer.elim_aux=true fp.spacer.reach_dnf=true fp.spacer.iuc=1 fp.spacer.iuc.arith=1 fp.validate=true fp.spacer.ground_pobs=true fp.spacer.mbqi=false fp.spacer.iuc.print_farkas_stats=false fp.spacer.iuc.old_hyp_reducer=false fp.spacer.ctp=true fp.spacer.weak_abs=true fp.spacer.native_mbp=true fp.spacer.conjecture=true fp.spacer.global=true fp.spacer.concretize=true fp.spacer.use_sage=false fp.spacer.use_iuc=true`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from typing import List


# noinspection PyUnresolvedReferences
pd.set_option('display.max_rows', None)
# noinspection PyUnresolvedReferences
pd.set_option('display.max_colwidth', None)

sns.set(style='ticks', palette='Set2')
# noinspection PyUnresolvedReferences
plt.rcParams['figure.figsize'] = (10, 10)

# %%
out_dir: str = '../../out/gspacer.hwmcc20-rules.lilla-my.29_10_2020-t17-01-38'

filename: str = 'gspacer.hwmcc20-rules.lilla-my.29_10_2020-t17-01-38.csv'
df: pd.DataFrame = pd.read_csv(filename)

df['status'].fillna(value='(no status)', inplace=True)

timeout = 900
df['time'].fillna(value=timeout, inplace=True)
df.loc[df['status'] == 'unknown', 'time'] = timeout

# show a snapshot of data for visual validation
df.head()
# Out:
#                                 index  SPACER_cex_depth  \
# 0    array-VexRiscv-regch0-15-p0.smt2               NaN
# 1    array-VexRiscv-regch0-15-p1.smt2               NaN
# 2    array-VexRiscv-regch0-20-p0.smt2               NaN
# 3  array-arbitrated_fifos_n2d8w8.smt2               NaN
# 4               array-array_swap.smt2               NaN
#
#    SPACER_cluster_out_of_gas  SPACER_conj  SPACER_conj_failed  \
# 0                        NaN          NaN                 NaN
# 1                        NaN          NaN                 NaN
# 2                        NaN          NaN                 NaN
# 3                        NaN          NaN                 NaN
# 4                        NaN          NaN                 NaN
#
#    SPACER_conj_success  SPACER_inductive_level  SPACER_max_depth  \
# 0                  NaN                     NaN               8.0
# 1                  NaN                     NaN               5.0
# 2                  NaN                     NaN               8.0
# 3                  NaN                     NaN               3.0
# 4                  NaN                     NaN               2.0
#
#    SPACER_max_query_lvl  SPACER_non_local_gen  ...  \
# 0                   8.0                   NaN  ...
# 1                   5.0                   NaN  ...
# 2                   8.0                   NaN  ...
# 3                   3.0                   NaN  ...
# 4                   1.0                   NaN  ...
#
#    time_spacer_init_rules_pt_init  time_spacer_mbp  time_spacer_solve  \
# 0                            0.06             1.00              31.57
# 1                            0.06             1.01              20.80
# 2                            0.06             0.32              14.67
# 3                            0.00             0.00               0.03
# 4                             NaN              NaN               0.01
#
#    time_spacer_solve_propagate  time_spacer_solve_reach  \
# 0                         0.91                    30.64
# 1                         0.23                    20.56
# 2                         2.24                    12.41
# 3                         0.00                     0.02
# 4                         0.00                     0.00
#
#    time_spacer_solve_reach_children  time_spacer_solve_reach_cluster  \
# 0                              1.39                             0.04
# 1                              1.48                             0.02
# 2                              0.51                             0.01
# 3                              0.00                              NaN
# 4                               NaN                              NaN
#
#    time_spacer_solve_reach_gen_bool_ind  time_spacer_solve_reach_gen_global  \
# 0                                 23.76                                 NaN
# 1                                 14.22                                 NaN
# 2                                  9.26                                 NaN
# 3                                  0.00                                 NaN
# 4                                   NaN                                 NaN
#
#    time_spacer_solve_reach_is_reach
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
# [5 rows x 50 columns]

# %%
# quick overview of solved/unsolved instances
df[['status', 'index']].groupby('status').count()
# Out:
#              index
# status
# (no status)     21
# sat             21
# timeout        197
# unknown        168
# unsat          232

# %%
df.query('status == "(no status)"')[['index', 'status']]
# Out:
#                                             index       status
# 80   array-dblclockfft_butterfly_ck2_r0-p173.smt2  (no status)
# 92   array-dblclockfft_butterfly_ck3_r0-p051.smt2  (no status)
# 98   array-dblclockfft_butterfly_ck3_r0-p090.smt2  (no status)
# 105  array-dblclockfft_butterfly_ck3_r1-p049.smt2  (no status)
# 135           array-marlann_compute_fail1-p0.smt2  (no status)
# 138           array-marlann_compute_fail2-p1.smt2  (no status)
# 139           array-marlann_compute_fail2-p2.smt2  (no status)
# 387                                  bv-cal4.smt2  (no status)
# 389                                 bv-cal81.smt2  (no status)
# 436                             bv-h_TreeArb.smt2  (no status)
# 570        bv-shift_register_top_w16_d128_e0.smt2  (no status)
# 571         bv-shift_register_top_w16_d16_e0.smt2  (no status)
# 572         bv-shift_register_top_w16_d32_e0.smt2  (no status)
# 573         bv-shift_register_top_w16_d64_e0.smt2  (no status)
# 576         bv-shift_register_top_w32_d16_e0.smt2  (no status)
# 579         bv-shift_register_top_w8_d128_e0.smt2  (no status)
# 607                   bv-zipcpu-busdelay-p00.smt2  (no status)
# 609                   bv-zipcpu-busdelay-p30.smt2  (no status)
# 612                   bv-zipcpu-busdelay-p46.smt2  (no status)
# 613                   bv-zipcpu-busdelay-p47.smt2  (no status)
# 634           bv-zipversa_composecrc_prf-p10.smt2  (no status)

# %%
# Find unknown results. Usually means that something went wrong, not just timeout.
unknown_df: pd.DataFrame = df.query('status == "unknown"')[['index', 'status']]

def get_error(index: str) -> str:
    with open(os.path.join(out_dir, index)) as f:
        return f.readline().strip()

unknown_df['error'] = unknown_df['index'].apply(get_error)
unknown_df.sort_values('error').head()
# Out:
#                                     index   status  \
# 315         bv-VexRiscv-regch0-15-p0.smt2  unknown
# 152      array-picorv32_mutBX_mem-p1.smt2  unknown
# 149      array-picorv32_mutAY_mem-p5.smt2  unknown
# 337  bv-arbitrated_top_n4_w16_d64_e0.smt2  unknown
# 332   bv-arbitrated_top_n3_w8_d16_e0.smt2  unknown
#
#                                                                                                                                            error
# 315          (error "query failed: Argument #b00 at position 1 does not match declaration (declare-fun bvule ((_ BitVec 1) (_ BitVec 1)) Bool)")
# 152          (error "query failed: Argument #b00 at position 1 does not match declaration (declare-fun bvule ((_ BitVec 1) (_ BitVec 1)) Bool)")
# 149       (error "query failed: Argument #b00000 at position 1 does not match declaration (declare-fun bvule ((_ BitVec 1) (_ BitVec 1)) Bool)")
# 337  (error "query failed: Argument #b11 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")
# 332  (error "query failed: Argument #b11 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")

# %%
unknown_df.groupby('error')[['index']].agg(['first', 'count'])
# Out:
#                                                                                                                                                                                                                      index  \
#                                                                                                                                                                                                                      first
# error
# (error "query failed: Argument #b00 at position 1 does not match declaration (declare-fun bvule ((_ BitVec 1) (_ BitVec 1)) Bool)")                                                       array-picorv32_mutBX_mem-p1.smt2
# (error "query failed: Argument #b00000 at position 1 does not match declaration (declare-fun bvule ((_ BitVec 1) (_ BitVec 1)) Bool)")                                                    array-picorv32_mutAY_mem-p5.smt2
# (error "query failed: Argument #b11 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")                                               array-picorv32_mutBX_mem-p2.smt2
# (error "query failed: Argument #b111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")                                                 array-picorv32-check-p01.smt2
# (error "query failed: Argument #b11111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")                                            array-VexRiscv-regch0-15-p0.smt2
# (error "query failed: Argument #b111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")                                       array-zipcpu_zipcpu_dcache-p126.smt2
# (error "query failed: Argument #b1111111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")                                               array-array_swap.smt2
# (error "query failed: Argument #b1111111111111111111111111111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")      array-dblclockfft_butterfly_ck3_r0-p042.smt2
# (error "query failed: Argument #b11111111111111111111111111111111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")  array-dblclockfft_butterfly_ck3_r1-p047.smt2
# (error "query failed: Argument #x00 at position 1 does not match declaration (declare-fun bvule ((_ BitVec 1) (_ BitVec 1)) Bool)")                                                    bv-marlann_compute_cp_fail1-p2.smt2
# (error "query failed: Argument #xffff at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")                                                 array-zipcpu-zipmmu-p00.smt2
# (error "query failed: operator is applied to arguments of the wrong sort")                                                                                                              array-arbitrated_fifos_n2d8w8.smt2
# (error "query failed: rule validation failed when checking: (exists ((x!1 Bool)                                                                                                  array-dblclockfft_butterfly_ck1-p063.smt2
#
#
#                                                                                                                                                                              count
# error
# (error "query failed: Argument #b00 at position 1 does not match declaration (declare-fun bvule ((_ BitVec 1) (_ BitVec 1)) Bool)")                                              2
# (error "query failed: Argument #b00000 at position 1 does not match declaration (declare-fun bvule ((_ BitVec 1) (_ BitVec 1)) Bool)")                                           1
# (error "query failed: Argument #b11 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")                                     24
# (error "query failed: Argument #b111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")                                    71
# (error "query failed: Argument #b11111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")                                  13
# (error "query failed: Argument #b111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")                                 17
# (error "query failed: Argument #b1111111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")                           2
# (error "query failed: Argument #b1111111111111111111111111111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")         1
# (error "query failed: Argument #b11111111111111111111111111111111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")     1
# (error "query failed: Argument #x00 at position 1 does not match declaration (declare-fun bvule ((_ BitVec 1) (_ BitVec 1)) Bool)")                                              3
# (error "query failed: Argument #xffff at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")                                    8
# (error "query failed: operator is applied to arguments of the wrong sort")                                                                                                       2
# (error "query failed: rule validation failed when checking: (exists ((x!1 Bool)                                                                                                 23

# %% [markdown]
# ## HWMCC20 modelcheckers

# %%
pd.read_csv('http://fmv.jku.at/hwmcc20/hwmcc20-combined-all.txt', delim_whitespace=True)
# Out:
#          cnt   ok  sat  uns  dis  fld   to  mo  unk    real     time    space  \
# avr      639  547   66  481    0   92    0   0   92   71456  1049649  2282407
# nuxmv    639  500   50  450    0  139  139   0    0   99664   339693   505974
# pono     639  386   58  328    0  253  219  22   12   63789   288937   596666
# cosa2    639  373   58  315    0  266  252   1   13  136153   537672   585138
# btormc   639  333   59  274    0  306  305   0    1   53822    53797    47550
# abc      324  262   56  206    0   62   62   0    0   36505   429078   344728
# abc17    324  262   55  207    0   62   62   0    0   39465   470045   352773
# pdtrav   324  245   45  200    0   79   76   0    3   74891   429930   713508
# avy      324  236   40  196    0   88   88   0    0   44055   437528   426064
# nmtip    324  210   17  193   26   88   88   0    0   24949    24933    17119
# camical  324   43   43    0    0  281  142   0  139   30048    30046     9821
#
#            max  best  uniq
# avr      49141   100    23
# nuxmv     6898    12     2
# pono     77761    38     1
# cosa2    14623    17     0
# btormc    2565   208     2
# abc      31293    29     1
# abc17    31820    10     1
# pdtrav   30090     8     2
# avy      14949    25     0
# nmtip     3117   142    13
# camical    945     8     0

# %%
# The values of the result column are unknown if all model checkers
# gives unknown, or if the number of model checkers that says sat
# and the number of those that say unsat tie. Otherwise, the values
# are sat or unsat based on the majority of the model checkers.
hwmcc20_results: pd.DataFrame = pd.read_csv('../hwmcc20-results.csv')
hwmcc20_results['index'] = hwmcc20_results['index'].apply(lambda idx: idx + '.smt2')
hwmcc20_results.head()
# Out:
#                                 index   result  sat_count  uns_count  \
# 0    array-VexRiscv-regch0-15-p0.smt2    unsat          0          5
# 1    array-VexRiscv-regch0-15-p1.smt2    unsat          0          5
# 2    array-VexRiscv-regch0-20-p0.smt2    unsat          0          4
# 3  array-arbitrated_fifos_n2d8w8.smt2  unknown          0          0
# 4               array-array_swap.smt2  unknown          0          0
#
#    unk_count  low_bound  high_bound  avg_bound  low_real  high_real  avg_real  \
# 0          0         -1          -1       -1.0      9.40    2857.39   586.858
# 1          0         -1          -1       -1.0      9.59    3105.02   641.160
# 2          0         -1          -1       -1.0    228.44    3600.10  1017.224
# 3          2         -1          -1       -1.0      0.74    3600.10  2874.864
# 4          2         -1          -1       -1.0      0.42    3600.10  2875.386
#
#    low_time  high_timeavg_time  low_mem  high_mem  avg_mem   avg_time  \
# 0      9.30                NaN     82.0    2633.0   1112.0   1779.746
# 1      9.46                NaN     79.0    4350.0   1388.4   1355.362
# 2    228.36                NaN    209.0   10376.0   3061.4   3822.140
# 3      1.46                NaN     82.0    4803.0   1544.2  10024.040
# 4      0.09                NaN     31.0   24699.0   9013.2  13639.468
#
#    high_time
# 0    8570.64
# 1    6296.49
# 2    8203.90
# 3   28426.36
# 4   46507.75

# %%
hwmcc20_results[['result', 'index']].groupby(['result']).count()
# Out:
#          index
# result
# sat         84
# unknown     43
# unsat      512

# %% [markdown]
# ## Compare Gspacer and HWMCC20 modelcheckers

# %%
m: pd.DataFrame = pd.merge(df, hwmcc20_results, on='index')
m.head()
# Out:
#                                 index  SPACER_cex_depth  \
# 0    array-VexRiscv-regch0-15-p0.smt2               NaN
# 1    array-VexRiscv-regch0-15-p1.smt2               NaN
# 2    array-VexRiscv-regch0-20-p0.smt2               NaN
# 3  array-arbitrated_fifos_n2d8w8.smt2               NaN
# 4               array-array_swap.smt2               NaN
#
#    SPACER_cluster_out_of_gas  SPACER_conj  SPACER_conj_failed  \
# 0                        NaN          NaN                 NaN
# 1                        NaN          NaN                 NaN
# 2                        NaN          NaN                 NaN
# 3                        NaN          NaN                 NaN
# 4                        NaN          NaN                 NaN
#
#    SPACER_conj_success  SPACER_inductive_level  SPACER_max_depth  \
# 0                  NaN                     NaN               8.0
# 1                  NaN                     NaN               5.0
# 2                  NaN                     NaN               8.0
# 3                  NaN                     NaN               3.0
# 4                  NaN                     NaN               2.0
#
#    SPACER_max_query_lvl  SPACER_non_local_gen  ...  low_real  high_real  \
# 0                   8.0                   NaN  ...      9.40    2857.39
# 1                   5.0                   NaN  ...      9.59    3105.02
# 2                   8.0                   NaN  ...    228.44    3600.10
# 3                   3.0                   NaN  ...      0.74    3600.10
# 4                   1.0                   NaN  ...      0.42    3600.10
#
#    avg_real  low_time  high_timeavg_time  low_mem  high_mem  avg_mem  \
# 0   586.858      9.30                NaN     82.0    2633.0   1112.0
# 1   641.160      9.46                NaN     79.0    4350.0   1388.4
# 2  1017.224    228.36                NaN    209.0   10376.0   3061.4
# 3  2874.864      1.46                NaN     82.0    4803.0   1544.2
# 4  2875.386      0.09                NaN     31.0   24699.0   9013.2
#
#     avg_time  high_time
# 0   1779.746    8570.64
# 1   1355.362    6296.49
# 2   3822.140    8203.90
# 3  10024.040   28426.36
# 4  13639.468   46507.75
#
# [5 rows x 67 columns]

# %%
m[['status', 'index', 'result']].groupby(['status', 'result']).count()
# Out:
#                      index
# status      result
# (no status) sat          8
#             unknown      1
#             unsat       12
# sat         sat         11
#             unsat       10
# timeout     sat         26
#             unknown     13
#             unsat      158
# unknown     sat         39
#             unknown     28
#             unsat      101
# unsat       unknown      1
#             unsat      231

# %%
# {sat|uns|unk}_count: The number of model checkers
#                      that gives {sat|unsat|unknown}
query_columns: List[str] = ['index', 'status', 'result', 'time', 'memory',
                            'sat_count', 'uns_count', 'unk_count']
m.query('status == "sat" & result == "unsat"')[query_columns].sort_values('time')
# Out:
#                                     index status result  time  memory  \
# 443                          bv-miim.smt2    sat  unsat  0.03    8.77
# 582                      bv-stack-p2.smt2    sat  unsat  0.04   10.47
# 585    bv-vcegar_arrays_itc99_b12_p2.smt2    sat  unsat  0.04    9.92
# 559                      bv-rast-p11.smt2    sat  unsat  0.06   10.53
# 424  bv-elevator.4.prop1-func-interl.smt2    sat  unsat  0.07   11.17
# 554                      bv-rast-p00.smt2    sat  unsat  0.07   11.12
# 561                      bv-rast-p16.smt2    sat  unsat  0.11   15.64
# 560                      bv-rast-p14.smt2    sat  unsat  0.12   15.64
# 562                      bv-rast-p17.smt2    sat  unsat  0.12   14.16
# 444     bv-msmie.3.prop1-func-interl.smt2    sat  unsat  0.36   32.25
#
#      sat_count  uns_count  unk_count
# 443          0          9          1
# 582          0         10          1
# 585          0          1          1
# 559          0         10          1
# 424          0          9          1
# 554          0          6          1
# 561          0          4          1
# 560          0          2          1
# 562          0          1          1
# 444          0          5          1

# %% [markdown]
# For `bv-vcegar_arrays_itc99_b12_p2.smt2` and `bv-rast-p17.smt2`, only nmtip says unsat.

# %%
m.query('status == "unsat" & result == "sat"')[query_columns].sort_values('time')
# Out:
# Empty DataFrame
# Columns: [index, status, result, time, memory, sat_count, uns_count, unk_count]
# Index: []

# %%
m.query('status == "sat" & result == "unknown"')[query_columns].sort_values('time')
# Out:
# Empty DataFrame
# Columns: [index, status, result, time, memory, sat_count, uns_count, unk_count]
# Index: []

# %%
m.query('status == "unsat" & result == "unknown"')[query_columns].sort_values('time')
# Out:
#                              index status   result  time  memory  sat_count  \
# 168  array-simple-stack-pred1.smt2  unsat  unknown  0.09   10.29          0
#
#      uns_count  unk_count
# 168          0          1

# %%
plt.xlim(0, timeout)
plt.ylim(0, timeout)
g = sns.scatterplot(x='time', y='avg_real', hue='status', style='result', data=m)
sns.despine()
x = np.linspace(0, timeout, 2)
g.plot(x, x)

# %% [markdown]
# ## BV

# %%
df['index'].str.startswith('bv')
df_bv: pd.DataFrame = df[df['index'].str.startswith('bv-')]
df_bv.head()
# Out:
#                                      index  SPACER_cex_depth  \
# 315          bv-VexRiscv-regch0-15-p0.smt2               NaN
# 316          bv-VexRiscv-regch0-20-p0.smt2               NaN
# 317          bv-VexRiscv-regch0-30-p1.smt2               NaN
# 318  bv-anderson.3.prop1-back-serstep.smt2               4.0
# 319  bv-arbitrated_top_n2_w128_d32_e0.smt2               NaN
#
#      SPACER_cluster_out_of_gas  SPACER_conj  SPACER_conj_failed  \
# 315                        NaN          NaN                 NaN
# 316                        NaN          NaN                 NaN
# 317                        NaN          NaN                 NaN
# 318                        NaN          NaN                 NaN
# 319                        NaN          NaN                 NaN
#
#      SPACER_conj_success  SPACER_inductive_level  SPACER_max_depth  \
# 315                  NaN                     NaN               5.0
# 316                  NaN                     NaN               5.0
# 317                  NaN                     NaN               7.0
# 318                  NaN                     NaN               4.0
# 319                  NaN                     NaN              12.0
#
#      SPACER_max_query_lvl  SPACER_non_local_gen  ...  \
# 315                   4.0                   NaN  ...
# 316                   5.0                   NaN  ...
# 317                   6.0                   NaN  ...
# 318                   4.0                   NaN  ...
# 319                  11.0                   1.0  ...
#
#      time_spacer_init_rules_pt_init  time_spacer_mbp  time_spacer_solve  \
# 315                            0.09             0.02               1.30
# 316                            0.09             0.18               5.31
# 317                            0.08             2.01              32.76
# 318                            0.00             0.01              16.10
# 319                            0.10            33.98             772.23
#
#      time_spacer_solve_propagate  time_spacer_solve_reach  \
# 315                         0.32                     0.96
# 316                         0.67                     4.63
# 317                         2.51                    30.24
# 318                         0.27                    15.83
# 319                       117.48                   654.71
#
#      time_spacer_solve_reach_children  time_spacer_solve_reach_cluster  \
# 315                              0.04                             0.00
# 316                              0.26                             0.00
# 317                              2.38                             0.03
# 318                              0.03                             0.00
# 319                             33.54                             7.57
#
#      time_spacer_solve_reach_gen_bool_ind  time_spacer_solve_reach_gen_global  \
# 315                                  0.45                                 NaN
# 316                                  3.05                                 NaN
# 317                                 21.85                                 NaN
# 318                                 11.41                                 NaN
# 319                                514.37                                0.43
#
#      time_spacer_solve_reach_is_reach
# 315                               NaN
# 316                               NaN
# 317                               NaN
# 318                              1.32
# 319                              3.15
#
# [5 rows x 50 columns]

# %%
# quick overview of solved/unsolved instances
df_bv[['status', 'index']].groupby(['status']).count()
# Out:
#              index
# status
# (no status)     14
# sat             21
# timeout        167
# unknown         47
# unsat           75

# %%
df_bv.query('status == "(no status)"')[['index', 'status']]
# Out:
#                                       index       status
# 387                            bv-cal4.smt2  (no status)
# 389                           bv-cal81.smt2  (no status)
# 436                       bv-h_TreeArb.smt2  (no status)
# 570  bv-shift_register_top_w16_d128_e0.smt2  (no status)
# 571   bv-shift_register_top_w16_d16_e0.smt2  (no status)
# 572   bv-shift_register_top_w16_d32_e0.smt2  (no status)
# 573   bv-shift_register_top_w16_d64_e0.smt2  (no status)
# 576   bv-shift_register_top_w32_d16_e0.smt2  (no status)
# 579   bv-shift_register_top_w8_d128_e0.smt2  (no status)
# 607             bv-zipcpu-busdelay-p00.smt2  (no status)
# 609             bv-zipcpu-busdelay-p30.smt2  (no status)
# 612             bv-zipcpu-busdelay-p46.smt2  (no status)
# 613             bv-zipcpu-busdelay-p47.smt2  (no status)
# 634     bv-zipversa_composecrc_prf-p10.smt2  (no status)

# %%
unknown_df_bv: pd.DataFrame = unknown_df[unknown_df['index'].str.startswith('bv-')]
unknown_df_bv.head()
# Out:
#                                      index   status  \
# 315          bv-VexRiscv-regch0-15-p0.smt2  unknown
# 316          bv-VexRiscv-regch0-20-p0.smt2  unknown
# 317          bv-VexRiscv-regch0-30-p1.smt2  unknown
# 326  bv-arbitrated_top_n3_w16_d128_e0.smt2  unknown
# 327   bv-arbitrated_top_n3_w16_d32_e0.smt2  unknown
#
#                                                                                                                                               error
# 315             (error "query failed: Argument #b00 at position 1 does not match declaration (declare-fun bvule ((_ BitVec 1) (_ BitVec 1)) Bool)")
# 316  (error "query failed: Argument #b11111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")
# 317  (error "query failed: Argument #b11111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")
# 326     (error "query failed: Argument #b11 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")
# 327     (error "query failed: Argument #b11 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")

# %%
unknown_df_bv.groupby('error')[['index']].agg(['first', 'count'])
# Out:
#                                                                                                                                                                                 index  \
#                                                                                                                                                                                 first
# error
# (error "query failed: Argument #b00 at position 1 does not match declaration (declare-fun bvule ((_ BitVec 1) (_ BitVec 1)) Bool)")                     bv-VexRiscv-regch0-15-p0.smt2
# (error "query failed: Argument #b11 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")     bv-arbitrated_top_n3_w16_d128_e0.smt2
# (error "query failed: Argument #b111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")    bv-arbitrated_top_n5_w128_d64_e0.smt2
# (error "query failed: Argument #b11111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")          bv-VexRiscv-regch0-20-p0.smt2
# (error "query failed: Argument #x00 at position 1 does not match declaration (declare-fun bvule ((_ BitVec 1) (_ BitVec 1)) Bool)")               bv-marlann_compute_cp_fail1-p2.smt2
#
#
#                                                                                                                                                count
# error
# (error "query failed: Argument #b00 at position 1 does not match declaration (declare-fun bvule ((_ BitVec 1) (_ BitVec 1)) Bool)")                1
# (error "query failed: Argument #b11 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")       16
# (error "query failed: Argument #b111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")      17
# (error "query failed: Argument #b11111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")    10
# (error "query failed: Argument #x00 at position 1 does not match declaration (declare-fun bvule ((_ BitVec 1) (_ BitVec 1)) Bool)")                3

# %%
hwmcc20_results_bv: pd.DataFrame = hwmcc20_results[hwmcc20_results['index'].str.startswith('bv-')]
hwmcc20_results_bv.head()
# Out:
#                                      index result  sat_count  uns_count  \
# 315          bv-VexRiscv-regch0-15-p0.smt2  unsat          0          8
# 316          bv-VexRiscv-regch0-20-p0.smt2  unsat          0          8
# 317          bv-VexRiscv-regch0-30-p1.smt2  unsat          0          6
# 318  bv-anderson.3.prop1-back-serstep.smt2    sat         11          0
# 319  bv-arbitrated_top_n2_w128_d32_e0.smt2    sat          5          0
#
#      unk_count  low_bound  high_bound  avg_bound  low_real  high_real  \
# 315          1         -1          -1  -1.000000      6.28    3600.11
# 316          1         -1          -1  -1.000000     52.68    3600.10
# 317          1         -1          -1  -1.000000    254.53    3600.11
# 318          0         -1           4   1.272727      0.03       3.13
# 319          0         -1          -1  -1.000000    591.76    3600.11
#
#         avg_real  low_time  high_timeavg_time  low_mem  high_mem  \
# 315   680.350909      6.19                NaN     91.0   16828.0
# 316   891.460909     52.59                NaN    161.0   31820.0
# 317  2101.825455    254.49                NaN    722.0  110681.0
# 318     0.594545      0.00                NaN      0.0    1753.0
# 319  2364.781818   1647.68                NaN    225.0   14825.0
#
#           avg_mem      avg_time  high_time
# 315   4166.545455   4722.890000   35991.59
# 316  10455.272727   6538.323636   35992.53
# 317  28088.818182  14905.270909   35903.45
# 318    309.363636      0.810909       4.54
# 319   5186.272727  15454.903636   44492.40

# %%
m_bv: pd.DataFrame = pd.merge(df_bv, hwmcc20_results_bv, on='index')
m_bv.head()
# Out:
#                                    index  SPACER_cex_depth  \
# 0          bv-VexRiscv-regch0-15-p0.smt2               NaN
# 1          bv-VexRiscv-regch0-20-p0.smt2               NaN
# 2          bv-VexRiscv-regch0-30-p1.smt2               NaN
# 3  bv-anderson.3.prop1-back-serstep.smt2               4.0
# 4  bv-arbitrated_top_n2_w128_d32_e0.smt2               NaN
#
#    SPACER_cluster_out_of_gas  SPACER_conj  SPACER_conj_failed  \
# 0                        NaN          NaN                 NaN
# 1                        NaN          NaN                 NaN
# 2                        NaN          NaN                 NaN
# 3                        NaN          NaN                 NaN
# 4                        NaN          NaN                 NaN
#
#    SPACER_conj_success  SPACER_inductive_level  SPACER_max_depth  \
# 0                  NaN                     NaN               5.0
# 1                  NaN                     NaN               5.0
# 2                  NaN                     NaN               7.0
# 3                  NaN                     NaN               4.0
# 4                  NaN                     NaN              12.0
#
#    SPACER_max_query_lvl  SPACER_non_local_gen  ...  low_real  high_real  \
# 0                   4.0                   NaN  ...      6.28    3600.11
# 1                   5.0                   NaN  ...     52.68    3600.10
# 2                   6.0                   NaN  ...    254.53    3600.11
# 3                   4.0                   NaN  ...      0.03       3.13
# 4                  11.0                   1.0  ...    591.76    3600.11
#
#       avg_real  low_time  high_timeavg_time  low_mem  high_mem       avg_mem  \
# 0   680.350909      6.19                NaN     91.0   16828.0   4166.545455
# 1   891.460909     52.59                NaN    161.0   31820.0  10455.272727
# 2  2101.825455    254.49                NaN    722.0  110681.0  28088.818182
# 3     0.594545      0.00                NaN      0.0    1753.0    309.363636
# 4  2364.781818   1647.68                NaN    225.0   14825.0   5186.272727
#
#        avg_time  high_time
# 0   4722.890000   35991.59
# 1   6538.323636   35992.53
# 2  14905.270909   35903.45
# 3      0.810909       4.54
# 4  15454.903636   44492.40
#
# [5 rows x 67 columns]

# %%
m_bv[['status', 'index', 'result']].groupby(['status', 'result']).count()
# Out:
#                      index
# status      result
# (no status) sat          5
#             unknown      1
#             unsat        8
# sat         sat         11
#             unsat       10
# timeout     sat         24
#             unknown     11
#             unsat      132
# unknown     sat         25
#             unknown      9
#             unsat       13
# unsat       unsat       75

# %%
plt.xlim(0, timeout)
plt.ylim(0, timeout)
g = sns.scatterplot(x='time', y='avg_real', hue='status', style='result', data=m_bv)
sns.despine()
x = np.linspace(0, timeout, 2)
g.plot(x, x)

# %% [markdown]
# ## Array

# %%
df_array: pd.DataFrame = df[df['index'].str.startswith('array-')]
df_array.head()
# Out:
#                                 index  SPACER_cex_depth  \
# 0    array-VexRiscv-regch0-15-p0.smt2               NaN
# 1    array-VexRiscv-regch0-15-p1.smt2               NaN
# 2    array-VexRiscv-regch0-20-p0.smt2               NaN
# 3  array-arbitrated_fifos_n2d8w8.smt2               NaN
# 4               array-array_swap.smt2               NaN
#
#    SPACER_cluster_out_of_gas  SPACER_conj  SPACER_conj_failed  \
# 0                        NaN          NaN                 NaN
# 1                        NaN          NaN                 NaN
# 2                        NaN          NaN                 NaN
# 3                        NaN          NaN                 NaN
# 4                        NaN          NaN                 NaN
#
#    SPACER_conj_success  SPACER_inductive_level  SPACER_max_depth  \
# 0                  NaN                     NaN               8.0
# 1                  NaN                     NaN               5.0
# 2                  NaN                     NaN               8.0
# 3                  NaN                     NaN               3.0
# 4                  NaN                     NaN               2.0
#
#    SPACER_max_query_lvl  SPACER_non_local_gen  ...  \
# 0                   8.0                   NaN  ...
# 1                   5.0                   NaN  ...
# 2                   8.0                   NaN  ...
# 3                   3.0                   NaN  ...
# 4                   1.0                   NaN  ...
#
#    time_spacer_init_rules_pt_init  time_spacer_mbp  time_spacer_solve  \
# 0                            0.06             1.00              31.57
# 1                            0.06             1.01              20.80
# 2                            0.06             0.32              14.67
# 3                            0.00             0.00               0.03
# 4                             NaN              NaN               0.01
#
#    time_spacer_solve_propagate  time_spacer_solve_reach  \
# 0                         0.91                    30.64
# 1                         0.23                    20.56
# 2                         2.24                    12.41
# 3                         0.00                     0.02
# 4                         0.00                     0.00
#
#    time_spacer_solve_reach_children  time_spacer_solve_reach_cluster  \
# 0                              1.39                             0.04
# 1                              1.48                             0.02
# 2                              0.51                             0.01
# 3                              0.00                              NaN
# 4                               NaN                              NaN
#
#    time_spacer_solve_reach_gen_bool_ind  time_spacer_solve_reach_gen_global  \
# 0                                 23.76                                 NaN
# 1                                 14.22                                 NaN
# 2                                  9.26                                 NaN
# 3                                  0.00                                 NaN
# 4                                   NaN                                 NaN
#
#    time_spacer_solve_reach_is_reach
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
# [5 rows x 50 columns]

# %%
# quick overview of solved/unsolved instances
df_array[['status', 'index']].groupby('status').count()
# Out:
#              index
# status
# (no status)      7
# timeout         30
# unknown        121
# unsat          157

# %%
df_array.query('status == "(no status)"')[['index', 'status']]
# Out:
#                                             index       status
# 80   array-dblclockfft_butterfly_ck2_r0-p173.smt2  (no status)
# 92   array-dblclockfft_butterfly_ck3_r0-p051.smt2  (no status)
# 98   array-dblclockfft_butterfly_ck3_r0-p090.smt2  (no status)
# 105  array-dblclockfft_butterfly_ck3_r1-p049.smt2  (no status)
# 135           array-marlann_compute_fail1-p0.smt2  (no status)
# 138           array-marlann_compute_fail2-p1.smt2  (no status)
# 139           array-marlann_compute_fail2-p2.smt2  (no status)

# %%
unknown_df_array: pd.DataFrame = unknown_df[unknown_df['index'].str.startswith('array-')]
unknown_df_array.head()
# Out:
#                                 index   status  \
# 0    array-VexRiscv-regch0-15-p0.smt2  unknown
# 1    array-VexRiscv-regch0-15-p1.smt2  unknown
# 2    array-VexRiscv-regch0-20-p0.smt2  unknown
# 3  array-arbitrated_fifos_n2d8w8.smt2  unknown
# 4               array-array_swap.smt2  unknown
#
#                                                                                                                                                     error
# 0          (error "query failed: Argument #b11111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")
# 1          (error "query failed: Argument #b11111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")
# 2          (error "query failed: Argument #b11111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")
# 3                                                                              (error "query failed: operator is applied to arguments of the wrong sort")
# 4  (error "query failed: Argument #b1111111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")

# %%
unknown_df.groupby('error')[['index']].agg(['first', 'count'])
# Out:
#                                                                                                                                                                                                                      index  \
#                                                                                                                                                                                                                      first
# error
# (error "query failed: Argument #b00 at position 1 does not match declaration (declare-fun bvule ((_ BitVec 1) (_ BitVec 1)) Bool)")                                                       array-picorv32_mutBX_mem-p1.smt2
# (error "query failed: Argument #b00000 at position 1 does not match declaration (declare-fun bvule ((_ BitVec 1) (_ BitVec 1)) Bool)")                                                    array-picorv32_mutAY_mem-p5.smt2
# (error "query failed: Argument #b11 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")                                               array-picorv32_mutBX_mem-p2.smt2
# (error "query failed: Argument #b111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")                                                 array-picorv32-check-p01.smt2
# (error "query failed: Argument #b11111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")                                            array-VexRiscv-regch0-15-p0.smt2
# (error "query failed: Argument #b111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")                                       array-zipcpu_zipcpu_dcache-p126.smt2
# (error "query failed: Argument #b1111111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")                                               array-array_swap.smt2
# (error "query failed: Argument #b1111111111111111111111111111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")      array-dblclockfft_butterfly_ck3_r0-p042.smt2
# (error "query failed: Argument #b11111111111111111111111111111111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")  array-dblclockfft_butterfly_ck3_r1-p047.smt2
# (error "query failed: Argument #x00 at position 1 does not match declaration (declare-fun bvule ((_ BitVec 1) (_ BitVec 1)) Bool)")                                                    bv-marlann_compute_cp_fail1-p2.smt2
# (error "query failed: Argument #xffff at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")                                                 array-zipcpu-zipmmu-p00.smt2
# (error "query failed: operator is applied to arguments of the wrong sort")                                                                                                              array-arbitrated_fifos_n2d8w8.smt2
# (error "query failed: rule validation failed when checking: (exists ((x!1 Bool)                                                                                                  array-dblclockfft_butterfly_ck1-p063.smt2
#
#
#                                                                                                                                                                              count
# error
# (error "query failed: Argument #b00 at position 1 does not match declaration (declare-fun bvule ((_ BitVec 1) (_ BitVec 1)) Bool)")                                              2
# (error "query failed: Argument #b00000 at position 1 does not match declaration (declare-fun bvule ((_ BitVec 1) (_ BitVec 1)) Bool)")                                           1
# (error "query failed: Argument #b11 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")                                     24
# (error "query failed: Argument #b111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")                                    71
# (error "query failed: Argument #b11111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")                                  13
# (error "query failed: Argument #b111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")                                 17
# (error "query failed: Argument #b1111111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 32) (_ BitVec 32)) (_ BitVec 32))")                           2
# (error "query failed: Argument #b1111111111111111111111111111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")         1
# (error "query failed: Argument #b11111111111111111111111111111111111 at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")     1
# (error "query failed: Argument #x00 at position 1 does not match declaration (declare-fun bvule ((_ BitVec 1) (_ BitVec 1)) Bool)")                                              3
# (error "query failed: Argument #xffff at position 1 does not match declaration (declare-fun bvadd ((_ BitVec 1) (_ BitVec 1)) (_ BitVec 1))")                                    8
# (error "query failed: operator is applied to arguments of the wrong sort")                                                                                                       2
# (error "query failed: rule validation failed when checking: (exists ((x!1 Bool)                                                                                                 23

# %%
hwmcc20_results_array: pd.DataFrame = hwmcc20_results[hwmcc20_results['index'].str.startswith('array-')]
hwmcc20_results_array.head()
# Out:
#                                 index   result  sat_count  uns_count  \
# 0    array-VexRiscv-regch0-15-p0.smt2    unsat          0          5
# 1    array-VexRiscv-regch0-15-p1.smt2    unsat          0          5
# 2    array-VexRiscv-regch0-20-p0.smt2    unsat          0          4
# 3  array-arbitrated_fifos_n2d8w8.smt2  unknown          0          0
# 4               array-array_swap.smt2  unknown          0          0
#
#    unk_count  low_bound  high_bound  avg_bound  low_real  high_real  avg_real  \
# 0          0         -1          -1       -1.0      9.40    2857.39   586.858
# 1          0         -1          -1       -1.0      9.59    3105.02   641.160
# 2          0         -1          -1       -1.0    228.44    3600.10  1017.224
# 3          2         -1          -1       -1.0      0.74    3600.10  2874.864
# 4          2         -1          -1       -1.0      0.42    3600.10  2875.386
#
#    low_time  high_timeavg_time  low_mem  high_mem  avg_mem   avg_time  \
# 0      9.30                NaN     82.0    2633.0   1112.0   1779.746
# 1      9.46                NaN     79.0    4350.0   1388.4   1355.362
# 2    228.36                NaN    209.0   10376.0   3061.4   3822.140
# 3      1.46                NaN     82.0    4803.0   1544.2  10024.040
# 4      0.09                NaN     31.0   24699.0   9013.2  13639.468
#
#    high_time
# 0    8570.64
# 1    6296.49
# 2    8203.90
# 3   28426.36
# 4   46507.75

# %%
m_array: pd.DataFrame = pd.merge(df_array, hwmcc20_results_array, on='index')
m_array.head()
# Out:
#                                 index  SPACER_cex_depth  \
# 0    array-VexRiscv-regch0-15-p0.smt2               NaN
# 1    array-VexRiscv-regch0-15-p1.smt2               NaN
# 2    array-VexRiscv-regch0-20-p0.smt2               NaN
# 3  array-arbitrated_fifos_n2d8w8.smt2               NaN
# 4               array-array_swap.smt2               NaN
#
#    SPACER_cluster_out_of_gas  SPACER_conj  SPACER_conj_failed  \
# 0                        NaN          NaN                 NaN
# 1                        NaN          NaN                 NaN
# 2                        NaN          NaN                 NaN
# 3                        NaN          NaN                 NaN
# 4                        NaN          NaN                 NaN
#
#    SPACER_conj_success  SPACER_inductive_level  SPACER_max_depth  \
# 0                  NaN                     NaN               8.0
# 1                  NaN                     NaN               5.0
# 2                  NaN                     NaN               8.0
# 3                  NaN                     NaN               3.0
# 4                  NaN                     NaN               2.0
#
#    SPACER_max_query_lvl  SPACER_non_local_gen  ...  low_real  high_real  \
# 0                   8.0                   NaN  ...      9.40    2857.39
# 1                   5.0                   NaN  ...      9.59    3105.02
# 2                   8.0                   NaN  ...    228.44    3600.10
# 3                   3.0                   NaN  ...      0.74    3600.10
# 4                   1.0                   NaN  ...      0.42    3600.10
#
#    avg_real  low_time  high_timeavg_time  low_mem  high_mem  avg_mem  \
# 0   586.858      9.30                NaN     82.0    2633.0   1112.0
# 1   641.160      9.46                NaN     79.0    4350.0   1388.4
# 2  1017.224    228.36                NaN    209.0   10376.0   3061.4
# 3  2874.864      1.46                NaN     82.0    4803.0   1544.2
# 4  2875.386      0.09                NaN     31.0   24699.0   9013.2
#
#     avg_time  high_time
# 0   1779.746    8570.64
# 1   1355.362    6296.49
# 2   3822.140    8203.90
# 3  10024.040   28426.36
# 4  13639.468   46507.75
#
# [5 rows x 67 columns]

# %%
m_array[['status', 'index', 'result']].groupby(['status', 'result']).count()
# Out:
#                      index
# status      result
# (no status) sat          3
#             unsat        4
# timeout     sat          2
#             unknown      2
#             unsat       26
# unknown     sat         14
#             unknown     19
#             unsat       88
# unsat       unknown      1
#             unsat      156

# %%
plt.xlim(0, timeout)
plt.ylim(0, timeout)
g = sns.scatterplot(x='time', y='avg_real', hue='status', style='result', data=m_array)
sns.despine()
x = np.linspace(0, timeout, 2)
g.plot(x, x)
